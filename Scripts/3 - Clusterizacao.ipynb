# %% [markdown]
# # Script clusterização para as bases de dados do ENEM - Algoritmo KMeans
#
# **Autor**: Rafael Victor Araujo Bernardes - rafaelvictor.bernardes@gmail.com

# %%
import pandas as pd
import numpy as np

from sklearn.cluster import KMeans

# %%
# Variáveis de controle

# ano = '2019'
# ano = '2020'
# ano = '2021'
# ano = '2022'
ano = '2023'

DATASET_ENEM_PATH = 'D:\BASES_PRE_PROCESSADAS\PRE_PROCESSADOS_ENEM_' + ano + '.csv'

# %%
microdadosEnem = pd.read_csv(DATASET_ENEM_PATH, sep=',', encoding='ISO-8859-1')

# %%
microdadosEnem.shape
# Out:
# (2678264, 169)

# %%
microdadosEnem.head()
# Out:
#    MEDIA_NOTAS  TP_FAIXA_ETARIA_1  TP_FAIXA_ETARIA_2  TP_FAIXA_ETARIA_3  \
# 0       507.94              False              False              False
# 1       564.28              False               True              False
# 2       425.38              False              False               True
# 3       617.12              False              False              False
# 4       697.66              False              False              False
#
#    TP_FAIXA_ETARIA_4  TP_FAIXA_ETARIA_5  TP_FAIXA_ETARIA_6  TP_FAIXA_ETARIA_7  \
# 0              False              False               True              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    TP_FAIXA_ETARIA_8  TP_FAIXA_ETARIA_9  ...  Q024_D  Q024_E  Q025_A  Q025_B  \
# 0              False              False  ...   False   False   False    True
# 1              False              False  ...   False   False   False    True
# 2              False              False  ...   False   False    True   False
# 3              False              False  ...   False   False   False    True
# 4               True              False  ...   False   False   False    True
#
#    MACRO_REGIAO_CENTRO_OESTE  MACRO_REGIAO_NORDESTE  MACRO_REGIAO_NORTE  \
# 0                      False                  False               False
# 1                      False                   True               False
# 2                      False                   True               False
# 3                      False                  False               False
# 4                      False                   True               False
#
#    MACRO_REGIAO_SUDESTE  MACRO_REGIAO_SUL  K_Cluster
# 0                 False              True          3
# 1                 False             False          0
# 2                 False             False          0
# 3                  True             False          3
# 4                 False             False          3
#
# [5 rows x 169 columns]

# %%
aux_init = "k-means++"
aux_n_init = "auto"
aux_n_clusters = 5
aux_max_iter = 10
aux_random_state = 72769

colunas_para_kmeans = [col for col in microdadosEnem.columns if col not in ['MEDIA_NOTAS', 'K_Cluster']]

# %%
microdadosEnem[colunas_para_kmeans].head()
# Out:
#    TP_FAIXA_ETARIA_1  TP_FAIXA_ETARIA_2  TP_FAIXA_ETARIA_3  TP_FAIXA_ETARIA_4  \
# 0              False              False              False              False
# 1              False               True              False              False
# 2              False              False               True              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    TP_FAIXA_ETARIA_5  TP_FAIXA_ETARIA_6  TP_FAIXA_ETARIA_7  TP_FAIXA_ETARIA_8  \
# 0              False               True              False              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False               True
#
#    TP_FAIXA_ETARIA_9  TP_FAIXA_ETARIA_10  ...  Q024_D  Q024_E  Q025_A  Q025_B  \
# 0              False               False  ...   False   False   False    True
# 1              False               False  ...   False   False   False    True
# 2              False               False  ...   False   False    True   False
# 3              False               False  ...   False   False   False    True
# 4              False               False  ...   False   False   False    True
#
#    MACRO_REGIAO_CENTRO_OESTE  MACRO_REGIAO_NORDESTE  MACRO_REGIAO_NORTE  \
# 0                      False                  False               False
# 1                      False                   True               False
# 2                      False                   True               False
# 3                      False                  False               False
# 4                      False                   True               False
#
#    MACRO_REGIAO_SUDESTE  MACRO_REGIAO_SUL  K_Cluster
# 0                 False              True          3
# 1                 False             False          0
# 2                 False             False          0
# 3                  True             False          3
# 4                 False             False          3
#
# [5 rows x 168 columns]

# %%
kmeans = KMeans(
    init         = aux_init
    n_clusters   = aux_n_clusters,
    n_init       = aux_n_init,
    max_iter     = aux_max_iter,
    random_state = aux_random_state
).fit(microdadosEnem[colunas_para_kmeans])

# %%
microdadosEnem['K_Cluster'] = kmeans.labels_
microdadosEnem.head()
# Out:
#    MEDIA_NOTAS  TP_FAIXA_ETARIA_1  TP_FAIXA_ETARIA_2  TP_FAIXA_ETARIA_3  \
# 0       507.94              False              False              False
# 1       564.28              False               True              False
# 2       425.38              False              False               True
# 3       617.12              False              False              False
# 4       697.66              False              False              False
#
#    TP_FAIXA_ETARIA_4  TP_FAIXA_ETARIA_5  TP_FAIXA_ETARIA_6  TP_FAIXA_ETARIA_7  \
# 0              False              False               True              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    TP_FAIXA_ETARIA_8  TP_FAIXA_ETARIA_9  ...  Q024_D  Q024_E  Q025_A  Q025_B  \
# 0              False              False  ...   False   False   False    True
# 1              False              False  ...   False   False   False    True
# 2              False              False  ...   False   False    True   False
# 3              False              False  ...   False   False   False    True
# 4               True              False  ...   False   False   False    True
#
#    MACRO_REGIAO_CENTRO_OESTE  MACRO_REGIAO_NORDESTE  MACRO_REGIAO_NORTE  \
# 0                      False                  False               False
# 1                      False                   True               False
# 2                      False                   True               False
# 3                      False                  False               False
# 4                      False                   True               False
#
#    MACRO_REGIAO_SUDESTE  MACRO_REGIAO_SUL  K_Cluster
# 0                 False              True          4
# 1                 False             False          0
# 2                 False             False          0
# 3                  True             False          4
# 4                 False             False          4
#
# [5 rows x 169 columns]

# %%
microdadosEnem.to_csv(DATASET_ENEM_PATH, sep=',', encoding='ISO-8859-1', index=False)

# %% [markdown]
# ## Caracterizações gerais

# %%
for cluster in np.sort(microdadosEnem.K_Cluster.unique()):
    quantidade_integrantes = (microdadosEnem.K_Cluster == cluster).sum()
    print(f'{cluster:d};Quantidade;{quantidade_integrantes}')

total_linhas_tabela = microdadosEnem.shape[0]
print(f'All;Quantidade;{total_linhas_tabela}')

for coluna in microdadosEnem.drop('K_Cluster', axis=1).columns:
    for cluster in np.sort(microdadosEnem.K_Cluster.unique()): # 0, 1, 2, 3, ou 4

        if coluna == 'MEDIA_NOTAS':
            media = microdadosEnem.loc[microdadosEnem.K_Cluster == cluster, coluna].mean()
            print(f'{cluster:d};{coluna};{media:.4f}'.replace('.', ','))

        else:
            registros_do_cluster = microdadosEnem.loc[microdadosEnem.K_Cluster == cluster, coluna].sum()
            porcentagem = (registros_do_cluster * 100) / total_linhas_tabela
            print(f'{cluster:d};{coluna};{porcentagem:.4f}%'.replace('.', ','))

for coluna in microdadosEnem.drop('K_Cluster', axis=1).columns:
    
    if coluna == 'MEDIA_NOTAS':
        media = microdadosEnem.loc[:, coluna].mean()
        print(f'All;{coluna};{media:.4f}'.replace('.', ','))

    else:
        registros_da_tabela = microdadosEnem.loc[:, coluna].sum()
        porcentagem = (registros_da_tabela * 100) / total_linhas_tabela
        print(f'All;{coluna};{porcentagem:.4f}%'.replace('.', ','))
# Out:
# 0;Quantidade;383750
# 1;Quantidade;827801
# 2;Quantidade;503585
# 3;Quantidade;353858
# 4;Quantidade;609270
# All;Quantidade;2678264
# 0;MEDIA_NOTAS;494,2913
# 1;MEDIA_NOTAS;507,3274
# 2;MEDIA_NOTAS;542,7544
# 3;MEDIA_NOTAS;617,2177
# 4;MEDIA_NOTAS;568,7329
# 0;TP_FAIXA_ETARIA_1;0,0983%
# 1;TP_FAIXA_ETARIA_1;3,0530%
# 2;TP_FAIXA_ETARIA_1;0,0813%
# 3;TP_FAIXA_ETARIA_1;3,0412%
# 4;TP_FAIXA_ETARIA_1;4,4987%
# 0;TP_FAIXA_ETARIA_2;4,5454%
# 1;TP_FAIXA_ETARIA_2;2,9761%
# 2;TP_FAIXA_ETARIA_2;7,3397%
# 3;TP_FAIXA_ETARIA_2;4,8729%
# 4;TP_FAIXA_ETARIA_2;3,4450%
# 0;TP_FAIXA_ETARIA_3;7,3407%
# 1;TP_FAIXA_ETARIA_3;2,5931%
# 2;TP_FAIXA_ETARIA_3;9,8954%
# 3;TP_FAIXA_ETARIA_3;3,2701%
# 4;TP_FAIXA_ETARIA_3;2,3957%
# 0;TP_FAIXA_ETARIA_4;1,4147%
# 1;TP_FAIXA_ETARIA_4;4,1120%
# 2;TP_FAIXA_ETARIA_4;1,1253%
# 3;TP_FAIXA_ETARIA_4;0,8724%
# 4;TP_FAIXA_ETARIA_4;3,3905%
# 0;TP_FAIXA_ETARIA_5;0,4018%
# 1;TP_FAIXA_ETARIA_5;3,1505%
# 2;TP_FAIXA_ETARIA_5;0,2074%
# 3;TP_FAIXA_ETARIA_5;0,3948%
# 4;TP_FAIXA_ETARIA_5;2,1690%
# 0;TP_FAIXA_ETARIA_6;0,1330%
# 1;TP_FAIXA_ETARIA_6;2,3137%
# 2;TP_FAIXA_ETARIA_6;0,0517%
# 3;TP_FAIXA_ETARIA_6;0,2007%
# 4;TP_FAIXA_ETARIA_6;1,3607%
# 0;TP_FAIXA_ETARIA_7;0,0626%
# 1;TP_FAIXA_ETARIA_7;1,8012%
# 2;TP_FAIXA_ETARIA_7;0,0179%
# 3;TP_FAIXA_ETARIA_7;0,1174%
# 4;TP_FAIXA_ETARIA_7;0,9063%
# 0;TP_FAIXA_ETARIA_8;0,0392%
# 1;TP_FAIXA_ETARIA_8;1,4263%
# 2;TP_FAIXA_ETARIA_8;0,0100%
# 3;TP_FAIXA_ETARIA_8;0,0771%
# 4;TP_FAIXA_ETARIA_8;0,6771%
# 0;TP_FAIXA_ETARIA_9;0,0268%
# 1;TP_FAIXA_ETARIA_9;1,1533%
# 2;TP_FAIXA_ETARIA_9;0,0060%
# 3;TP_FAIXA_ETARIA_9;0,0527%
# 4;TP_FAIXA_ETARIA_9;0,5044%
# 0;TP_FAIXA_ETARIA_10;0,0205%
# 1;TP_FAIXA_ETARIA_10;0,9069%
# 2;TP_FAIXA_ETARIA_10;0,0047%
# 3;TP_FAIXA_ETARIA_10;0,0391%
# 4;TP_FAIXA_ETARIA_10;0,3771%
# 0;TP_FAIXA_ETARIA_11;0,0753%
# 1;TP_FAIXA_ETARIA_11;2,9730%
# 2;TP_FAIXA_ETARIA_11;0,0137%
# 3;TP_FAIXA_ETARIA_11;0,0979%
# 4;TP_FAIXA_ETARIA_11;1,1125%
# 0;TP_FAIXA_ETARIA_12;0,0500%
# 1;TP_FAIXA_ETARIA_12;1,5419%
# 2;TP_FAIXA_ETARIA_12;0,0090%
# 3;TP_FAIXA_ETARIA_12;0,0463%
# 4;TP_FAIXA_ETARIA_12;0,6012%
# 0;TP_FAIXA_ETARIA_13;0,1198%
# 1;TP_FAIXA_ETARIA_13;2,9071%
# 2;TP_FAIXA_ETARIA_13;0,0405%
# 3;TP_FAIXA_ETARIA_13;0,1297%
# 4;TP_FAIXA_ETARIA_13;1,3103%
# 0;TP_SEXO_F;9,3063%
# 1;TP_SEXO_F;20,5934%
# 2;TP_SEXO_F;10,7957%
# 3;TP_SEXO_F;7,1491%
# 4;TP_SEXO_F;13,5402%
# 0;TP_SEXO_M;5,0220%
# 1;TP_SEXO_M;10,3147%
# 2;TP_SEXO_M;8,0069%
# 3;TP_SEXO_M;6,0631%
# 4;TP_SEXO_M;9,2085%
# 0;TP_ESTADO_CIVIL_0;0,6237%
# 1;TP_ESTADO_CIVIL_0;1,2965%
# 2;TP_ESTADO_CIVIL_0;0,6849%
# 3;TP_ESTADO_CIVIL_0;0,4534%
# 4;TP_ESTADO_CIVIL_0;0,8310%
# 0;TP_ESTADO_CIVIL_1;13,4555%
# 1;TP_ESTADO_CIVIL_1;26,7770%
# 2;TP_ESTADO_CIVIL_1;17,8842%
# 3;TP_ESTADO_CIVIL_1;12,5340%
# 4;TP_ESTADO_CIVIL_1;20,4973%
# 0;TP_ESTADO_CIVIL_2;0,1393%
# 1;TP_ESTADO_CIVIL_2;2,1098%
# 2;TP_ESTADO_CIVIL_2;0,0892%
# 3;TP_ESTADO_CIVIL_2;0,1343%
# 4;TP_ESTADO_CIVIL_2;1,1132%
# 0;TP_ESTADO_CIVIL_3;0,1037%
# 1;TP_ESTADO_CIVIL_3;0,6691%
# 2;TP_ESTADO_CIVIL_3;0,1407%
# 3;TP_ESTADO_CIVIL_3;0,0871%
# 4;TP_ESTADO_CIVIL_3;0,2841%
# 0;TP_ESTADO_CIVIL_4;0,0062%
# 1;TP_ESTADO_CIVIL_4;0,0557%
# 2;TP_ESTADO_CIVIL_4;0,0037%
# 3;TP_ESTADO_CIVIL_4;0,0034%
# 4;TP_ESTADO_CIVIL_4;0,0231%
# 0;TP_COR_RACA_0;0,1962%
# 1;TP_COR_RACA_0;0,4117%
# 2;TP_COR_RACA_0;0,1875%
# 3;TP_COR_RACA_0;0,1376%
# 4;TP_COR_RACA_0;0,3077%
# 0;TP_COR_RACA_1;3,2419%
# 1;TP_COR_RACA_1;7,4905%
# 2;TP_COR_RACA_1;9,6423%
# 3;TP_COR_RACA_1;10,3527%
# 4;TP_COR_RACA_1;12,3521%
# 0;TP_COR_RACA_2;2,1428%
# 1;TP_COR_RACA_2;5,2434%
# 2;TP_COR_RACA_2;1,9411%
# 3;TP_COR_RACA_2;0,4141%
# 4;TP_COR_RACA_2;2,0944%
# 0;TP_COR_RACA_3;8,3776%
# 1;TP_COR_RACA_3;16,9733%
# 2;TP_COR_RACA_3;6,7165%
# 3;TP_COR_RACA_3;2,0349%
# 4;TP_COR_RACA_3;7,6123%
# 0;TP_COR_RACA_4;0,2347%
# 1;TP_COR_RACA_4;0,5275%
# 2;TP_COR_RACA_4;0,2473%
# 3;TP_COR_RACA_4;0,2590%
# 4;TP_COR_RACA_4;0,3248%
# 0;TP_COR_RACA_5;0,1350%
# 1;TP_COR_RACA_5;0,2617%
# 2;TP_COR_RACA_5;0,0678%
# 3;TP_COR_RACA_5;0,0139%
# 4;TP_COR_RACA_5;0,0574%
# 0;TP_NACIONALIDADE_0;0,0129%
# 1;TP_NACIONALIDADE_0;0,0126%
# 2;TP_NACIONALIDADE_0;0,0093%
# 3;TP_NACIONALIDADE_0;0,0047%
# 4;TP_NACIONALIDADE_0;0,0069%
# 0;TP_NACIONALIDADE_1;13,9285%
# 1;TP_NACIONALIDADE_1;30,1344%
# 2;TP_NACIONALIDADE_1;18,3468%
# 3;TP_NACIONALIDADE_1;13,0274%
# 4;TP_NACIONALIDADE_1;22,3272%
# 0;TP_NACIONALIDADE_2;0,3420%
# 1;TP_NACIONALIDADE_2;0,6804%
# 2;TP_NACIONALIDADE_2;0,3475%
# 3;TP_NACIONALIDADE_2;0,1020%
# 4;TP_NACIONALIDADE_2;0,3055%
# 0;TP_NACIONALIDADE_3;0,0242%
# 1;TP_NACIONALIDADE_3;0,0471%
# 2;TP_NACIONALIDADE_3;0,0433%
# 3;TP_NACIONALIDADE_3;0,0212%
# 4;TP_NACIONALIDADE_3;0,0394%
# 0;TP_NACIONALIDADE_4;0,0206%
# 1;TP_NACIONALIDADE_4;0,0336%
# 2;TP_NACIONALIDADE_4;0,0557%
# 3;TP_NACIONALIDADE_4;0,0570%
# 4;TP_NACIONALIDADE_4;0,0697%
# 0;TP_ST_CONCLUSAO_1;0,0000%
# 1;TP_ST_CONCLUSAO_1;24,3398%
# 2;TP_ST_CONCLUSAO_1;0,0000%
# 3;TP_ST_CONCLUSAO_1;2,4334%
# 4;TP_ST_CONCLUSAO_1;14,5215%
# 0;TP_ST_CONCLUSAO_2;14,3283%
# 1;TP_ST_CONCLUSAO_2;0,0001%
# 2;TP_ST_CONCLUSAO_2;18,8026%
# 3;TP_ST_CONCLUSAO_2;6,0571%
# 4;TP_ST_CONCLUSAO_2;0,0486%
# 0;TP_ST_CONCLUSAO_3;0,0000%
# 1;TP_ST_CONCLUSAO_3;6,4296%
# 2;TP_ST_CONCLUSAO_3;0,0001%
# 3;TP_ST_CONCLUSAO_3;4,6257%
# 4;TP_ST_CONCLUSAO_3;8,0398%
# 0;TP_ST_CONCLUSAO_4;0,0000%
# 1;TP_ST_CONCLUSAO_4;0,1386%
# 2;TP_ST_CONCLUSAO_4;0,0000%
# 3;TP_ST_CONCLUSAO_4;0,0960%
# 4;TP_ST_CONCLUSAO_4;0,1387%
# 0;TP_ESCOLA_1;0,0000%
# 1;TP_ESCOLA_1;30,9080%
# 2;TP_ESCOLA_1;0,0001%
# 3;TP_ESCOLA_1;7,1552%
# 4;TP_ESCOLA_1;22,7002%
# 0;TP_ESCOLA_2;13,8936%
# 1;TP_ESCOLA_2;0,0000%
# 2;TP_ESCOLA_2;15,6623%
# 3;TP_ESCOLA_2;1,4168%
# 4;TP_ESCOLA_2;0,0000%
# 0;TP_ESCOLA_3;0,4348%
# 1;TP_ESCOLA_3;0,0001%
# 2;TP_ESCOLA_3;3,1402%
# 3;TP_ESCOLA_3;4,6403%
# 4;TP_ESCOLA_3;0,0485%
# 0;Q001_A;0,8954%
# 1;Q001_A;2,2692%
# 2;Q001_A;0,1637%
# 3;Q001_A;0,0138%
# 4;Q001_A;0,2550%
# 0;Q001_B;3,2655%
# 1;Q001_B;8,3830%
# 2;Q001_B;1,5908%
# 3;Q001_B;0,1480%
# 4;Q001_B;1,9235%
# 0;Q001_C;2,3384%
# 1;Q001_C;4,8423%
# 2;Q001_C;2,3072%
# 3;Q001_C;0,3678%
# 4;Q001_C;2,5192%
# 0;Q001_D;1,9338%
# 1;Q001_D;3,5019%
# 2;Q001_D;2,5426%
# 3;Q001_D;0,5995%
# 4;Q001_D;2,5201%
# 0;Q001_E;3,2323%
# 1;Q001_E;7,1878%
# 2;Q001_E;7,7219%
# 3;Q001_E;2,8782%
# 4;Q001_E;9,1924%
# 0;Q001_F;0,3323%
# 1;Q001_F;0,9335%
# 2;Q001_F;1,7867%
# 3;Q001_F;3,8981%
# 4;Q001_F;3,1232%
# 0;Q001_G;0,1504%
# 1;Q001_G;0,3940%
# 2;Q001_G;0,8714%
# 3;Q001_G;4,8912%
# 4;Q001_G;1,7060%
# 0;Q001_H;2,1801%
# 1;Q001_H;3,3965%
# 2;Q001_H;1,8185%
# 3;Q001_H;0,4156%
# 4;Q001_H;1,5092%
# 0;Q002_A;0,4662%
# 1;Q002_A;1,4261%
# 2;Q002_A;0,0775%
# 3;Q002_A;0,0076%
# 4;Q002_A;0,1797%
# 0;Q002_B;2,2296%
# 1;Q002_B;6,1447%
# 2;Q002_B;0,8524%
# 3;Q002_B;0,0661%
# 4;Q002_B;1,1758%
# 0;Q002_C;2,1781%
# 1;Q002_C;4,4430%
# 2;Q002_C;1,5031%
# 3;Q002_C;0,1560%
# 4;Q002_C;1,6392%
# 0;Q002_D;2,4048%
# 1;Q002_D;4,2321%
# 2;Q002_D;2,2768%
# 3;Q002_D;0,3359%
# 4;Q002_D;2,0994%
# 0;Q002_E;5,0325%
# 1;Q002_E;10,7194%
# 2;Q002_E;8,7128%
# 3;Q002_E;2,3756%
# 4;Q002_E;9,4126%
# 0;Q002_F;0,7544%
# 1;Q002_F;1,8951%
# 2;Q002_F;2,6257%
# 3;Q002_F;4,0583%
# 4;Q002_F;4,0788%
# 0;Q002_G;0,4355%
# 1;Q002_G;1,1852%
# 2;Q002_G;2,1593%
# 3;Q002_G;6,0327%
# 4;Q002_G;3,7366%
# 0;Q002_H;0,8272%
# 1;Q002_H;0,8625%
# 2;Q002_H;0,5950%
# 3;Q002_H;0,1801%
# 4;Q002_H;0,4267%
# 0;Q003_A;4,5953%
# 1;Q003_A;9,6169%
# 2;Q003_A;1,4298%
# 3;Q003_A;0,2728%
# 4;Q003_A;1,5760%
# 0;Q003_B;3,4088%
# 1;Q003_B;7,5389%
# 2;Q003_B;3,6952%
# 3;Q003_B;0,4762%
# 4;Q003_B;3,7919%
# 0;Q003_C;2,9123%
# 1;Q003_C;6,7976%
# 2;Q003_C;6,0562%
# 3;Q003_C;0,8269%
# 4;Q003_C;6,2194%
# 0;Q003_D;0,8968%
# 1;Q003_D;2,3908%
# 2;Q003_D;4,5297%
# 3;Q003_D;5,3745%
# 4;Q003_D;7,4721%
# 0;Q003_E;0,0849%
# 1;Q003_E;0,2630%
# 2;Q003_E;0,7237%
# 3;Q003_E;5,6538%
# 4;Q003_E;1,4733%
# 0;Q003_F;2,4302%
# 1;Q003_F;4,3009%
# 2;Q003_F;2,3681%
# 3;Q003_F;0,6080%
# 4;Q003_F;2,2159%
# 0;Q004_A;3,9662%
# 1;Q004_A;8,2603%
# 2;Q004_A;0,7807%
# 3;Q004_A;0,0998%
# 4;Q004_A;0,8998%
# 0;Q004_B;6,6086%
# 1;Q004_B;14,8766%
# 2;Q004_B;8,2188%
# 3;Q004_B;1,1173%
# 4;Q004_B;8,2882%
# 0;Q004_C;0,7919%
# 1;Q004_C;1,6828%
# 2;Q004_C;1,6747%
# 3;Q004_C;0,2860%
# 4;Q004_C;1,6630%
# 0;Q004_D;1,3456%
# 1;Q004_D;3,4876%
# 2;Q004_D;5,6756%
# 3;Q004_D;6,5929%
# 4;Q004_D;8,8917%
# 0;Q004_E;0,0677%
# 1;Q004_E;0,1783%
# 2;Q004_E;0,5692%
# 3;Q004_E;4,2411%
# 4;Q004_E;1,0832%
# 0;Q004_F;1,5483%
# 1;Q004_F;2,4226%
# 2;Q004_F;1,8837%
# 3;Q004_F;0,8750%
# 4;Q004_F;1,9228%
# 0;Q005_1;0,1288%
# 1;Q005_1;2,1104%
# 2;Q005_1;0,0415%
# 3;Q005_1;0,0257%
# 4;Q005_1;0,3967%
# 0;Q005_2;1,7807%
# 1;Q005_2;5,6377%
# 2;Q005_2;1,9947%
# 3;Q005_2;0,7170%
# 4;Q005_2;2,9402%
# 0;Q005_3;3,6219%
# 1;Q005_3;7,8412%
# 2;Q005_3;5,9015%
# 3;Q005_3;3,4977%
# 4;Q005_3;7,3903%
# 0;Q005_4;4,4493%
# 1;Q005_4;8,1249%
# 2;Q005_4;6,7965%
# 3;Q005_4;6,4552%
# 4;Q005_4;7,9267%
# 0;Q005_5;4,3476%
# 1;Q005_5;7,1940%
# 2;Q005_5;4,0685%
# 3;Q005_5;2,5166%
# 4;Q005_5;4,0949%
# 0;Q006_A;1,8056%
# 1;Q006_A;3,5051%
# 2;Q006_A;0,2741%
# 3;Q006_A;0,0346%
# 4;Q006_A;0,1902%
# 0;Q006_B;8,9505%
# 1;Q006_B;15,7397%
# 2;Q006_B;2,6295%
# 3;Q006_B;0,0625%
# 4;Q006_B;1,7079%
# 0;Q006_C;2,1868%
# 1;Q006_C;6,2772%
# 2;Q006_C;3,7103%
# 3;Q006_C;0,1284%
# 4;Q006_C;3,1716%
# 0;Q006_D;0,8098%
# 1;Q006_D;2,8905%
# 2;Q006_D;3,4027%
# 3;Q006_D;0,2635%
# 4;Q006_D;3,6808%
# 0;Q006_E;0,3028%
# 1;Q006_E;1,2141%
# 2;Q006_E;2,6131%
# 3;Q006_E;0,4286%
# 4;Q006_E;3,2642%
# 0;Q006_F;0,1168%
# 1;Q006_F;0,5009%
# 2;Q006_F;1,5725%
# 3;Q006_F;0,4384%
# 4;Q006_F;2,1209%
# 0;Q006_G;0,0983%
# 1;Q006_G;0,4665%
# 2;Q006_G;2,2305%
# 3;Q006_G;1,2109%
# 4;Q006_G;3,5253%
# 0;Q006_H;0,0284%
# 1;Q006_H;0,1467%
# 2;Q006_H;0,9735%
# 3;Q006_H;1,1925%
# 4;Q006_H;1,7822%
# 0;Q006_I;0,0132%
# 1;Q006_I;0,0655%
# 2;Q006_I;0,5177%
# 3;Q006_I;0,9417%
# 4;Q006_I;1,0543%
# 0;Q006_J;0,0078%
# 1;Q006_J;0,0394%
# 2;Q006_J;0,3693%
# 3;Q006_J;1,0583%
# 4;Q006_J;0,8284%
# 0;Q006_K;0,0028%
# 1;Q006_K;0,0230%
# 2;Q006_K;0,2185%
# 3;Q006_K;1,0570%
# 4;Q006_K;0,5393%
# 0;Q006_L;0,0056%
# 1;Q006_L;0,0394%
# 2;Q006_L;0,2909%
# 3;Q006_L;6,3958%
# 4;Q006_L;0,8833%
# 0;Q007_A;13,8486%
# 1;Q007_A;30,1358%
# 2;Q007_A;18,1312%
# 3;Q007_A;7,0693%
# 4;Q007_A;21,6426%
# 0;Q007_B;0,2649%
# 1;Q007_B;0,4529%
# 2;Q007_B;0,3561%
# 3;Q007_B;3,3048%
# 4;Q007_B;0,6741%
# 0;Q007_C;0,0681%
# 1;Q007_C;0,1041%
# 2;Q007_C;0,1023%
# 3;Q007_C;0,6957%
# 4;Q007_C;0,1475%
# 0;Q007_D;0,1467%
# 1;Q007_D;0,2153%
# 2;Q007_D;0,2130%
# 3;Q007_D;2,1424%
# 4;Q007_D;0,2845%
# 0;Q008_A;0,3479%
# 1;Q008_A;0,4576%
# 2;Q008_A;0,0189%
# 3;Q008_A;0,0040%
# 4;Q008_A;0,0146%
# 0;Q008_B;13,0302%
# 1;Q008_B;28,1468%
# 2;Q008_B;11,0975%
# 3;Q008_B;0,6979%
# 4;Q008_B;10,1304%
# 0;Q008_C;0,8923%
# 1;Q008_C;2,1583%
# 2;Q008_C;6,5169%
# 3;Q008_C;4,1663%
# 4;Q008_C;10,2542%
# 0;Q008_D;0,0512%
# 1;Q008_D;0,1294%
# 2;Q008_D;1,0042%
# 3;Q008_D;4,5542%
# 4;Q008_D;1,9689%
# 0;Q008_E;0,0066%
# 1;Q008_E;0,0160%
# 2;Q008_E;0,1652%
# 3;Q008_E;3,7899%
# 4;Q008_E;0,3807%
# 0;Q009_A;0,2263%
# 1;Q009_A;0,4323%
# 2;Q009_A;0,0293%
# 3;Q009_A;0,0019%
# 4;Q009_A;0,0251%
# 0;Q009_B;2,9617%
# 1;Q009_B;7,1218%
# 2;Q009_B;0,8053%
# 3;Q009_B;0,0281%
# 4;Q009_B;0,8574%
# 0;Q009_C;8,7154%
# 1;Q009_C;18,3644%
# 2;Q009_C;10,0228%
# 3;Q009_C;1,6517%
# 4;Q009_C;10,4828%
# 0;Q009_D;2,2059%
# 1;Q009_D;4,5836%
# 2;Q009_D;7,1327%
# 3;Q009_D;8,3652%
# 4;Q009_D;10,1966%
# 0;Q009_E;0,2191%
# 1;Q009_E;0,4060%
# 2;Q009_E;0,8125%
# 3;Q009_E;3,1653%
# 4;Q009_E;1,1868%
# 0;Q010_A;12,7420%
# 1;Q010_A;26,5919%
# 2;Q010_A;5,4284%
# 3;Q010_A;0,4191%
# 4;Q010_A;5,0524%
# 0;Q010_B;1,5425%
# 1;Q010_B;4,1910%
# 2;Q010_B;11,8681%
# 3;Q010_B;5,5542%
# 4;Q010_B;15,3551%
# 0;Q010_C;0,0393%
# 1;Q010_C;0,1160%
# 2;Q010_C;1,3689%
# 3;Q010_C;6,1083%
# 4;Q010_C;2,1417%
# 0;Q010_D;0,0033%
# 1;Q010_D;0,0074%
# 2;Q010_D;0,1169%
# 3;Q010_D;0,9132%
# 4;Q010_D;0,1726%
# 0;Q010_E;0,0012%
# 1;Q010_E;0,0020%
# 2;Q010_E;0,0203%
# 3;Q010_E;0,2174%
# 4;Q010_E;0,0268%
# 0;Q011_A;10,5906%
# 1;Q011_A;23,5101%
# 2;Q011_A;13,5111%
# 3;Q011_A;10,9138%
# 4;Q011_A;16,5701%
# 0;Q011_B;3,4590%
# 1;Q011_B;6,8858%
# 2;Q011_B;4,5484%
# 3;Q011_B;1,8592%
# 4;Q011_B;5,2891%
# 0;Q011_C;0,2582%
# 1;Q011_C;0,4820%
# 2;Q011_C;0,6668%
# 3;Q011_C;0,3502%
# 4;Q011_C;0,8018%
# 0;Q011_D;0,0187%
# 1;Q011_D;0,0278%
# 2;Q011_D;0,0660%
# 3;Q011_D;0,0650%
# 4;Q011_D;0,0767%
# 0;Q011_E;0,0018%
# 1;Q011_E;0,0024%
# 2;Q011_E;0,0103%
# 3;Q011_E;0,0240%
# 4;Q011_E;0,0110%
# 0;Q012_A;0,5687%
# 1;Q012_A;0,9766%
# 2;Q012_A;0,0469%
# 3;Q012_A;0,0060%
# 4;Q012_A;0,0431%
# 0;Q012_B;13,6554%
# 1;Q012_B;29,7516%
# 2;Q012_B;17,8887%
# 3;Q012_B;9,5978%
# 4;Q012_B;21,6063%
# 0;Q012_C;0,1004%
# 1;Q012_C;0,1736%
# 2;Q012_C;0,8212%
# 3;Q012_C;3,2002%
# 4;Q012_C;1,0541%
# 0;Q012_D;0,0031%
# 1;Q012_D;0,0050%
# 2;Q012_D;0,0398%
# 3;Q012_D;0,3349%
# 4;Q012_D;0,0395%
# 0;Q012_E;0,0007%
# 1;Q012_E;0,0012%
# 2;Q012_E;0,0061%
# 3;Q012_E;0,0733%
# 4;Q012_E;0,0056%
# 0;Q013_A;11,9604%
# 1;Q013_A;24,5024%
# 2;Q013_A;6,8930%
# 3;Q013_A;1,9674%
# 4;Q013_A;7,7196%
# 0;Q013_B;2,3300%
# 1;Q013_B;6,3313%
# 2;Q013_B;11,3211%
# 3;Q013_B;8,6188%
# 4;Q013_B;14,3007%
# 0;Q013_C;0,0347%
# 1;Q013_C;0,0675%
# 2;Q013_C;0,5228%
# 3;Q013_C;2,2244%
# 4;Q013_C;0,6553%
# 0;Q013_D;0,0025%
# 1;Q013_D;0,0052%
# 2;Q013_D;0,0521%
# 3;Q013_D;0,3317%
# 4;Q013_D;0,0592%
# 0;Q013_E;0,0008%
# 1;Q013_E;0,0018%
# 2;Q013_E;0,0135%
# 3;Q013_E;0,0699%
# 4;Q013_E;0,0139%
# 0;Q014_A;11,1956%
# 1;Q014_A;21,3241%
# 2;Q014_A;1,6796%
# 3;Q014_A;0,1487%
# 4;Q014_A;1,6906%
# 0;Q014_B;3,1114%
# 1;Q014_B;9,5545%
# 2;Q014_B;16,8486%
# 3;Q014_B;12,3455%
# 4;Q014_B;20,7991%
# 0;Q014_C;0,0206%
# 1;Q014_C;0,0283%
# 2;Q014_C;0,2645%
# 3;Q014_C;0,6807%
# 4;Q014_C;0,2505%
# 0;Q014_D;0,0006%
# 1;Q014_D;0,0009%
# 2;Q014_D;0,0088%
# 3;Q014_D;0,0302%
# 4;Q014_D;0,0068%
# 0;Q014_E;0,0001%
# 1;Q014_E;0,0004%
# 2;Q014_E;0,0012%
# 3;Q014_E;0,0070%
# 4;Q014_E;0,0017%
# 0;Q015_A;13,9770%
# 1;Q015_A;29,9317%
# 2;Q015_A;15,7251%
# 3;Q015_A;7,9235%
# 4;Q015_A;19,0545%
# 0;Q015_B;0,3490%
# 1;Q015_B;0,9725%
# 2;Q015_B;3,0457%
# 3;Q015_B;5,1747%
# 4;Q015_B;3,6664%
# 0;Q015_C;0,0019%
# 1;Q015_C;0,0031%
# 2;Q015_C;0,0299%
# 3;Q015_C;0,1019%
# 4;Q015_C;0,0255%
# 0;Q015_D;0,0002%
# 1;Q015_D;0,0004%
# 2;Q015_D;0,0016%
# 3;Q015_D;0,0079%
# 4;Q015_D;0,0014%
# 0;Q015_E;0,0002%
# 1;Q015_E;0,0004%
# 2;Q015_E;0,0003%
# 3;Q015_E;0,0043%
# 4;Q015_E;0,0010%
# 0;Q016_A;12,6236%
# 1;Q016_A;25,2882%
# 2;Q016_A;5,3659%
# 3;Q016_A;0,8150%
# 4;Q016_A;5,3506%
# 0;Q016_B;1,6993%
# 1;Q016_B;5,6118%
# 2;Q016_B;13,3174%
# 3;Q016_B;11,7872%
# 4;Q016_B;17,2810%
# 0;Q016_C;0,0048%
# 1;Q016_C;0,0072%
# 2;Q016_C;0,1143%
# 3;Q016_C;0,5689%
# 4;Q016_C;0,1126%
# 0;Q016_D;0,0003%
# 1;Q016_D;0,0005%
# 2;Q016_D;0,0039%
# 3;Q016_D;0,0322%
# 4;Q016_D;0,0035%
# 0;Q016_E;0,0003%
# 1;Q016_E;0,0003%
# 2;Q016_E;0,0013%
# 3;Q016_E;0,0089%
# 4;Q016_E;0,0009%
# 0;Q017_A;14,2576%
# 1;Q017_A;30,7787%
# 2;Q017_A;18,4875%
# 3;Q017_A;10,4177%
# 4;Q017_A;22,2654%
# 0;Q017_B;0,0698%
# 1;Q017_B;0,1273%
# 2;Q017_B;0,3089%
# 3;Q017_B;2,7382%
# 4;Q017_B;0,4778%
# 0;Q017_C;0,0006%
# 1;Q017_C;0,0010%
# 2;Q017_C;0,0053%
# 3;Q017_C;0,0479%
# 4;Q017_C;0,0041%
# 0;Q017_D;0,0001%
# 1;Q017_D;0,0005%
# 2;Q017_D;0,0006%
# 3;Q017_D;0,0044%
# 4;Q017_D;0,0006%
# 0;Q017_E;0,0002%
# 1;Q017_E;0,0006%
# 2;Q017_E;0,0003%
# 3;Q017_E;0,0040%
# 4;Q017_E;0,0007%
# 0;Q018_A;14,1886%
# 1;Q018_A;30,2927%
# 2;Q018_A;13,1825%
# 3;Q018_A;2,0384%
# 4;Q018_A;14,3925%
# 0;Q018_B;0,1397%
# 1;Q018_B;0,6154%
# 2;Q018_B;5,6202%
# 3;Q018_B;11,1738%
# 4;Q018_B;8,3562%
# 0;Q019_A;1,8545%
# 1;Q019_A;3,7987%
# 2;Q019_A;0,5459%
# 3;Q019_A;0,0456%
# 4;Q019_A;0,5964%
# 0;Q019_B;11,9717%
# 1;Q019_B;25,7522%
# 2;Q019_B;11,9262%
# 3;Q019_B;1,7094%
# 4;Q019_B;12,5224%
# 0;Q019_C;0,4644%
# 1;Q019_C;1,2582%
# 2;Q019_C;4,9177%
# 3;Q019_C;4,4305%
# 4;Q019_C;7,3710%
# 0;Q019_D;0,0337%
# 1;Q019_D;0,0899%
# 2;Q019_D;1,2060%
# 3;Q019_D;3,9616%
# 4;Q019_D;1,9004%
# 0;Q019_E;0,0040%
# 1;Q019_E;0,0092%
# 2;Q019_E;0,2069%
# 3;Q019_E;3,0652%
# 4;Q019_E;0,3585%
# 0;Q020_A;13,3640%
# 1;Q020_A;29,0692%
# 2;Q020_A;16,2537%
# 3;Q020_A;7,6259%
# 4;Q020_A;19,5366%
# 0;Q020_B;0,9643%
# 1;Q020_B;1,8390%
# 2;Q020_B;2,5490%
# 3;Q020_B;5,5863%
# 4;Q020_B;3,2121%
# 0;Q021_A;13,5524%
# 1;Q021_A;29,2972%
# 2;Q021_A;14,0710%
# 3;Q021_A;3,2691%
# 4;Q021_A;16,3675%
# 0;Q021_B;0,7760%
# 1;Q021_B;1,6109%
# 2;Q021_B;4,7316%
# 3;Q021_B;9,9431%
# 4;Q021_B;6,3812%
# 0;Q022_A;0,6241%
# 1;Q022_A;0,8810%
# 2;Q022_A;0,3946%
# 3;Q022_A;0,1581%
# 4;Q022_A;0,3154%
# 0;Q022_B;4,3870%
# 1;Q022_B;9,6073%
# 2;Q022_B;1,0972%
# 3;Q022_B;0,2498%
# 4;Q022_B;1,1824%
# 0;Q022_C;5,4156%
# 1;Q022_C;11,7643%
# 2;Q022_C;3,7188%
# 3;Q022_C;0,7434%
# 4;Q022_C;4,5987%
# 0;Q022_D;2,8210%
# 1;Q022_D;6,3335%
# 2;Q022_D;8,1717%
# 3;Q022_D;3,9290%
# 4;Q022_D;9,7795%
# 0;Q022_E;1,0806%
# 1;Q022_E;2,3220%
# 2;Q022_E;5,4204%
# 3;Q022_E;8,1321%
# 4;Q022_E;6,8727%
# 0;Q023_A;14,0341%
# 1;Q023_A;30,0632%
# 2;Q023_A;16,8293%
# 3;Q023_A;9,1506%
# 4;Q023_A;19,8298%
# 0;Q023_B;0,2942%
# 1;Q023_B;0,8449%
# 2;Q023_B;1,9734%
# 3;Q023_B;4,0617%
# 4;Q023_B;2,9189%
# 0;Q024_A;12,8512%
# 1;Q024_A;23,2239%
# 2;Q024_A;6,8590%
# 3;Q024_A;0,4782%
# 4;Q024_A;4,5198%
# 0;Q024_B;1,4133%
# 1;Q024_B;7,2687%
# 2;Q024_B;10,0341%
# 3;Q024_B;3,3945%
# 4;Q024_B;14,0163%
# 0;Q024_C;0,0578%
# 1;Q024_C;0,3752%
# 2;Q024_C;1,5764%
# 3;Q024_C;4,6877%
# 4;Q024_C;3,3772%
# 0;Q024_D;0,0053%
# 1;Q024_D;0,0342%
# 2;Q024_D;0,2778%
# 3;Q024_D;2,9063%
# 4;Q024_D;0,6903%
# 0;Q024_E;0,0007%
# 1;Q024_E;0,0061%
# 2;Q024_E;0,0554%
# 3;Q024_E;1,7455%
# 4;Q024_E;0,1452%
# 0;Q025_A;2,9499%
# 1;Q025_A;4,9762%
# 2;Q025_A;0,2258%
# 3;Q025_A;0,0110%
# 4;Q025_A;0,1418%
# 0;Q025_B;11,3785%
# 1;Q025_B;25,9319%
# 2;Q025_B;18,5769%
# 3;Q025_B;13,2012%
# 4;Q025_B;22,6069%
# 0;MACRO_REGIAO_CENTRO_OESTE;0,8277%
# 1;MACRO_REGIAO_CENTRO_OESTE;1,6334%
# 2;MACRO_REGIAO_CENTRO_OESTE;2,1694%
# 3;MACRO_REGIAO_CENTRO_OESTE;1,3885%
# 4;MACRO_REGIAO_CENTRO_OESTE;2,1707%
# 0;MACRO_REGIAO_NORDESTE;8,9297%
# 1;MACRO_REGIAO_NORDESTE;17,2601%
# 2;MACRO_REGIAO_NORDESTE;3,2684%
# 3;MACRO_REGIAO_NORDESTE;2,1736%
# 4;MACRO_REGIAO_NORDESTE;5,4191%
# 0;MACRO_REGIAO_NORTE;2,1623%
# 1;MACRO_REGIAO_NORTE;4,9323%
# 2;MACRO_REGIAO_NORTE;1,3557%
# 3;MACRO_REGIAO_NORTE;0,5769%
# 4;MACRO_REGIAO_NORTE;1,6201%
# 0;MACRO_REGIAO_SUDESTE;1,9621%
# 1;MACRO_REGIAO_SUDESTE;5,8276%
# 2;MACRO_REGIAO_SUDESTE;8,5930%
# 3;MACRO_REGIAO_SUDESTE;6,6620%
# 4;MACRO_REGIAO_SUDESTE;10,3065%
# 0;MACRO_REGIAO_SUL;0,4466%
# 1;MACRO_REGIAO_SUL;1,2547%
# 2;MACRO_REGIAO_SUL;3,4163%
# 3;MACRO_REGIAO_SUL;2,4112%
# 4;MACRO_REGIAO_SUL;3,2323%
# All;MEDIA_NOTAS;540,6086
# All;TP_FAIXA_ETARIA_1;10,7725%
# All;TP_FAIXA_ETARIA_2;23,1791%
# All;TP_FAIXA_ETARIA_3;25,4951%
# All;TP_FAIXA_ETARIA_4;10,9149%
# All;TP_FAIXA_ETARIA_5;6,3235%
# All;TP_FAIXA_ETARIA_6;4,0599%
# All;TP_FAIXA_ETARIA_7;2,9054%
# All;TP_FAIXA_ETARIA_8;2,2298%
# All;TP_FAIXA_ETARIA_9;1,7433%
# All;TP_FAIXA_ETARIA_10;1,3483%
# All;TP_FAIXA_ETARIA_11;4,2724%
# All;TP_FAIXA_ETARIA_12;2,2485%
# All;TP_FAIXA_ETARIA_13;4,5074%
# All;TP_SEXO_F;61,3848%
# All;TP_SEXO_M;38,6152%
# All;TP_ESTADO_CIVIL_0;3,8895%
# All;TP_ESTADO_CIVIL_1;91,1480%
# All;TP_ESTADO_CIVIL_2;3,5858%
# All;TP_ESTADO_CIVIL_3;1,2848%
# All;TP_ESTADO_CIVIL_4;0,0920%
# All;TP_COR_RACA_0;1,2407%
# All;TP_COR_RACA_1;43,0795%
# All;TP_COR_RACA_2;11,8359%
# All;TP_COR_RACA_3;41,7146%
# All;TP_COR_RACA_4;1,5933%
# All;TP_COR_RACA_5;0,5359%
# All;TP_NACIONALIDADE_0;0,0464%
# All;TP_NACIONALIDADE_1;97,7643%
# All;TP_NACIONALIDADE_2;1,7775%
# All;TP_NACIONALIDADE_3;0,1751%
# All;TP_NACIONALIDADE_4;0,2366%
# All;TP_ST_CONCLUSAO_1;41,2947%
# All;TP_ST_CONCLUSAO_2;39,2367%
# All;TP_ST_CONCLUSAO_3;19,0952%
# All;TP_ST_CONCLUSAO_4;0,3733%
# All;TP_ESCOLA_1;60,7635%
# All;TP_ESCOLA_2;30,9727%
# All;TP_ESCOLA_3;8,2639%
# All;Q001_A;3,5971%
# All;Q001_B;15,3109%
# All;Q001_C;12,3748%
# All;Q001_D;11,0980%
# All;Q001_E;30,2126%
# All;Q001_F;10,0738%
# All;Q001_G;8,0130%
# All;Q001_H;9,3199%
# All;Q002_A;2,1570%
# All;Q002_B;10,4686%
# All;Q002_C;9,9193%
# All;Q002_D;11,3490%
# All;Q002_E;36,2528%
# All;Q002_F;13,4123%
# All;Q002_G;13,5493%
# All;Q002_H;2,8915%
# All;Q003_A;17,4908%
# All;Q003_B;18,9111%
# All;Q003_C;22,8125%
# All;Q003_D;20,6639%
# All;Q003_E;8,1987%
# All;Q003_F;11,9232%
# All;Q004_A;14,0068%
# All;Q004_B;39,1095%
# All;Q004_C;6,0983%
# All;Q004_D;25,9934%
# All;Q004_E;6,1396%
# All;Q004_F;8,6524%
# All;Q005_1;2,7031%
# All;Q005_2;13,0704%
# All;Q005_3;28,2526%
# All;Q005_4;33,7525%
# All;Q005_5;22,2214%
# All;Q006_A;5,8097%
# All;Q006_B;29,0901%
# All;Q006_C;15,4744%
# All;Q006_D;11,0473%
# All;Q006_E;7,8228%
# All;Q006_F;4,7496%
# All;Q006_G;7,5315%
# All;Q006_H;4,1233%
# All;Q006_I;2,5924%
# All;Q006_J;2,3032%
# All;Q006_K;1,8406%
# All;Q006_L;7,6150%
# All;Q007_A;90,8275%
# All;Q007_B;5,0528%
# All;Q007_C;1,1179%
# All;Q007_D;3,0018%
# All;Q008_A;0,8431%
# All;Q008_B;63,1027%
# All;Q008_C;23,9880%
# All;Q008_D;7,7078%
# All;Q008_E;4,3584%
# All;Q009_A;0,7149%
# All;Q009_B;11,7743%
# All;Q009_C;49,2372%
# All;Q009_D;32,4840%
# All;Q009_E;5,7896%
# All;Q010_A;50,2337%
# All;Q010_B;38,5110%
# All;Q010_C;9,7742%
# All;Q010_D;1,2135%
# All;Q010_E;0,2676%
# All;Q011_A;75,0958%
# All;Q011_B;22,0415%
# All;Q011_C;2,5591%
# All;Q011_D;0,2541%
# All;Q011_E;0,0495%
# All;Q012_A;1,6412%
# All;Q012_B;92,4999%
# All;Q012_C;5,3496%
# All;Q012_D;0,4223%
# All;Q012_E;0,0870%
# All;Q013_A;53,0428%
# All;Q013_B;42,9019%
# All;Q013_C;3,5048%
# All;Q013_D;0,4506%
# All;Q013_E;0,0998%
# All;Q014_A;36,0386%
# All;Q014_B;62,6591%
# All;Q014_C;1,2445%
# All;Q014_D;0,0473%
# All;Q014_E;0,0104%
# All;Q015_A;86,6117%
# All;Q015_B;13,2082%
# All;Q015_C;0,1622%
# All;Q015_D;0,0116%
# All;Q015_E;0,0062%
# All;Q016_A;49,4432%
# All;Q016_B;49,6966%
# All;Q016_C;0,8078%
# All;Q016_D;0,0405%
# All;Q016_E;0,0118%
# All;Q017_A;96,2070%
# All;Q017_B;3,7221%
# All;Q017_C;0,0588%
# All;Q017_D;0,0063%
# All;Q017_E;0,0058%
# All;Q018_A;74,0948%
# All;Q018_B;25,9052%
# All;Q019_A;6,8410%
# All;Q019_B;63,8819%
# All;Q019_C;18,4419%
# All;Q019_D;7,1915%
# All;Q019_E;3,6437%
# All;Q020_A;85,8493%
# All;Q020_B;14,1507%
# All;Q021_A;76,5572%
# All;Q021_B;23,4428%
# All;Q022_A;2,3733%
# All;Q022_B;16,5236%
# All;Q022_C;26,2408%
# All;Q022_D;31,0347%
# All;Q022_E;23,8277%
# All;Q023_A;89,9070%
# All;Q023_B;10,0930%
# All;Q024_A;47,9321%
# All;Q024_B;36,1269%
# All;Q024_C;10,0742%
# All;Q024_D;3,9140%
# All;Q024_E;1,9528%
# All;Q025_A;8,3046%
# All;Q025_B;91,6954%
# All;MACRO_REGIAO_CENTRO_OESTE;8,1896%
# All;MACRO_REGIAO_NORDESTE;37,0510%
# All;MACRO_REGIAO_NORTE;10,6472%
# All;MACRO_REGIAO_SUDESTE;33,3512%
# All;MACRO_REGIAO_SUL;10,7611%
