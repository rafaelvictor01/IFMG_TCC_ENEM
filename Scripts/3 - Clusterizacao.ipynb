# %% [markdown]
# # Script clusterização para as bases de dados do ENEM - Algoritmo KMeans
#
# **Autor**: Rafael Victor Araujo Bernardes - rafaelvictor.bernardes@gmail.com

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.cluster import KMeans

# %%
# Variáveis de controle

# ano = '2019'
# ano = '2020'
# ano = '2021'
# ano = '2022'
ano = '2023'

DATASET_ENEM_PATH = 'D:\BASES_PRE_PROCESSADAS\PRE_PROCESSADOS_ENEM_' + ano + '.csv'

# %%
microdadosEnem = pd.read_csv(DATASET_ENEM_PATH, sep=',', encoding='ISO-8859-1')

# %%
microdadosEnem.shape
# Out:
# (2678264, 168)

# %%
microdadosEnem.head()
# Out:
#    MEDIA_NOTAS  TP_FAIXA_ETARIA_1  TP_FAIXA_ETARIA_2  TP_FAIXA_ETARIA_3  \
# 0       507.94              False              False              False
# 1       564.28              False               True              False
# 2       425.38              False              False               True
# 3       617.12              False              False              False
# 4       697.66              False              False              False
#
#    TP_FAIXA_ETARIA_4  TP_FAIXA_ETARIA_5  TP_FAIXA_ETARIA_6  TP_FAIXA_ETARIA_7  \
# 0              False              False               True              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    TP_FAIXA_ETARIA_8  TP_FAIXA_ETARIA_9  ...  Q024_C  Q024_D  Q024_E  Q025_A  \
# 0              False              False  ...   False   False   False   False
# 1              False              False  ...   False   False   False   False
# 2              False              False  ...   False   False   False    True
# 3              False              False  ...   False   False   False   False
# 4               True              False  ...   False   False   False   False
#
#    Q025_B  MACRO_REGIAO_CENTRO_OESTE  MACRO_REGIAO_NORDESTE  \
# 0    True                      False                  False
# 1    True                      False                   True
# 2   False                      False                   True
# 3    True                      False                  False
# 4    True                      False                   True
#
#    MACRO_REGIAO_NORTE  MACRO_REGIAO_SUDESTE  MACRO_REGIAO_SUL
# 0               False                 False              True
# 1               False                 False             False
# 2               False                 False             False
# 3               False                  True             False
# 4               False                 False             False
#
# [5 rows x 168 columns]

# %%
aux_n_init = 1
aux_max_iter = 10
n_clusters = 5
colunas_para_kmeans = [col for col in microdadosEnem.columns if col not in ['MEDIA_NOTAS']]

# %%
microdadosEnem[colunas_para_kmeans].head()
# Out:
#    TP_FAIXA_ETARIA_1  TP_FAIXA_ETARIA_2  TP_FAIXA_ETARIA_3  TP_FAIXA_ETARIA_4  \
# 0              False              False              False              False
# 1              False               True              False              False
# 2              False              False               True              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    TP_FAIXA_ETARIA_5  TP_FAIXA_ETARIA_6  TP_FAIXA_ETARIA_7  TP_FAIXA_ETARIA_8  \
# 0              False               True              False              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False               True
#
#    TP_FAIXA_ETARIA_9  TP_FAIXA_ETARIA_10  ...  Q024_C  Q024_D  Q024_E  Q025_A  \
# 0              False               False  ...   False   False   False   False
# 1              False               False  ...   False   False   False   False
# 2              False               False  ...   False   False   False    True
# 3              False               False  ...   False   False   False   False
# 4              False               False  ...   False   False   False   False
#
#    Q025_B  MACRO_REGIAO_CENTRO_OESTE  MACRO_REGIAO_NORDESTE  \
# 0    True                      False                  False
# 1    True                      False                   True
# 2   False                      False                   True
# 3    True                      False                  False
# 4    True                      False                   True
#
#    MACRO_REGIAO_NORTE  MACRO_REGIAO_SUDESTE  MACRO_REGIAO_SUL
# 0               False                 False              True
# 1               False                 False             False
# 2               False                 False             False
# 3               False                  True             False
# 4               False                 False             False
#
# [5 rows x 167 columns]

# %%
kmeans = KMeans(n_clusters=n_clusters, n_init=aux_n_init, max_iter=aux_max_iter, random_state=72769).fit(microdadosEnem[colunas_para_kmeans])

# %%
microdadosEnem['K_Cluster'] = kmeans.labels_
microdadosEnem.head()
# Out:
#    MEDIA_NOTAS  TP_FAIXA_ETARIA_1  TP_FAIXA_ETARIA_2  TP_FAIXA_ETARIA_3  \
# 0       507.94              False              False              False
# 1       564.28              False               True              False
# 2       425.38              False              False               True
# 3       617.12              False              False              False
# 4       697.66              False              False              False
#
#    TP_FAIXA_ETARIA_4  TP_FAIXA_ETARIA_5  TP_FAIXA_ETARIA_6  TP_FAIXA_ETARIA_7  \
# 0              False              False               True              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    TP_FAIXA_ETARIA_8  TP_FAIXA_ETARIA_9  ...  Q024_D  Q024_E  Q025_A  Q025_B  \
# 0              False              False  ...   False   False   False    True
# 1              False              False  ...   False   False   False    True
# 2              False              False  ...   False   False    True   False
# 3              False              False  ...   False   False   False    True
# 4               True              False  ...   False   False   False    True
#
#    MACRO_REGIAO_CENTRO_OESTE  MACRO_REGIAO_NORDESTE  MACRO_REGIAO_NORTE  \
# 0                      False                  False               False
# 1                      False                   True               False
# 2                      False                   True               False
# 3                      False                  False               False
# 4                      False                   True               False
#
#    MACRO_REGIAO_SUDESTE  MACRO_REGIAO_SUL  K_Cluster
# 0                 False              True          3
# 1                 False             False          0
# 2                 False             False          0
# 3                  True             False          3
# 4                 False             False          3
#
# [5 rows x 169 columns]

# %%
for cluster in np.sort(microdadosEnem.K_Cluster.unique()):
    quantidade_integrantes = (microdadosEnem.K_Cluster == cluster).sum()
    print(f'{cluster:d};Quantidade;{quantidade_integrantes}')

total_linhas_tabela = microdadosEnem.shape[0]
print(f'All;Quantidade;{total_linhas_tabela}')

for coluna in microdadosEnem.drop('K_Cluster', axis=1).columns:
    for cluster in np.sort(microdadosEnem.K_Cluster.unique()): # 0, 1, 2, 3, ou 4

        if coluna == 'MEDIA_NOTAS':
            media = microdadosEnem.loc[microdadosEnem.K_Cluster == cluster, coluna].mean()
            print(f'{cluster:d};{coluna};{media:.4f}'.replace('.', ','))

        else:
            registros_do_cluster = microdadosEnem.loc[microdadosEnem.K_Cluster == cluster, coluna].sum()
            porcentagem = (registros_do_cluster * 100) / total_linhas_tabela
            print(f'{cluster:d};{coluna};{porcentagem:.4f}%'.replace('.', ','))

for coluna in microdadosEnem.drop('K_Cluster', axis=1).columns:
    
    if coluna == 'MEDIA_NOTAS':
        media = microdadosEnem.loc[:, coluna].mean()
        print(f'All;{coluna};{media:.4f}'.replace('.', ','))

    else:
        registros_da_tabela = microdadosEnem.loc[:, coluna].sum()
        porcentagem = (registros_da_tabela * 100) / total_linhas_tabela
        print(f'All;{coluna};{porcentagem:.4f}%'.replace('.', ','))
# Out:
# 0;Quantidade;383750
# 1;Quantidade;827801
# 2;Quantidade;353713
# 3;Quantidade;613796
# 4;Quantidade;499204
# All;Quantidade;2678264
# 0;MEDIA_NOTAS;494,2913
# 1;MEDIA_NOTAS;507,3274
# 2;MEDIA_NOTAS;617,2122
# 3;MEDIA_NOTAS;569,0983
# 4;MEDIA_NOTAS;542,0951
# 0;TP_FAIXA_ETARIA_1;0,0983%
# 1;TP_FAIXA_ETARIA_1;3,0530%
# 2;TP_FAIXA_ETARIA_1;3,0411%
# 3;TP_FAIXA_ETARIA_1;4,4991%
# 4;TP_FAIXA_ETARIA_1;0,0810%
# 0;TP_FAIXA_ETARIA_2;4,5454%
# 1;TP_FAIXA_ETARIA_2;2,9761%
# 2;TP_FAIXA_ETARIA_2;4,8682%
# 3;TP_FAIXA_ETARIA_2;3,5711%
# 4;TP_FAIXA_ETARIA_2;7,2184%
# 0;TP_FAIXA_ETARIA_3;7,3407%
# 1;TP_FAIXA_ETARIA_3;2,5931%
# 2;TP_FAIXA_ETARIA_3;3,2697%
# 3;TP_FAIXA_ETARIA_3;2,4350%
# 4;TP_FAIXA_ETARIA_3;9,8566%
# 0;TP_FAIXA_ETARIA_4;1,4147%
# 1;TP_FAIXA_ETARIA_4;4,1120%
# 2;TP_FAIXA_ETARIA_4;0,8722%
# 3;TP_FAIXA_ETARIA_4;3,3936%
# 4;TP_FAIXA_ETARIA_4;1,1224%
# 0;TP_FAIXA_ETARIA_5;0,4018%
# 1;TP_FAIXA_ETARIA_5;3,1505%
# 2;TP_FAIXA_ETARIA_5;0,3948%
# 3;TP_FAIXA_ETARIA_5;2,1692%
# 4;TP_FAIXA_ETARIA_5;0,2071%
# 0;TP_FAIXA_ETARIA_6;0,1330%
# 1;TP_FAIXA_ETARIA_6;2,3137%
# 2;TP_FAIXA_ETARIA_6;0,2007%
# 3;TP_FAIXA_ETARIA_6;1,3608%
# 4;TP_FAIXA_ETARIA_6;0,0517%
# 0;TP_FAIXA_ETARIA_7;0,0626%
# 1;TP_FAIXA_ETARIA_7;1,8012%
# 2;TP_FAIXA_ETARIA_7;0,1174%
# 3;TP_FAIXA_ETARIA_7;0,9063%
# 4;TP_FAIXA_ETARIA_7;0,0179%
# 0;TP_FAIXA_ETARIA_8;0,0392%
# 1;TP_FAIXA_ETARIA_8;1,4263%
# 2;TP_FAIXA_ETARIA_8;0,0771%
# 3;TP_FAIXA_ETARIA_8;0,6771%
# 4;TP_FAIXA_ETARIA_8;0,0100%
# 0;TP_FAIXA_ETARIA_9;0,0268%
# 1;TP_FAIXA_ETARIA_9;1,1533%
# 2;TP_FAIXA_ETARIA_9;0,0527%
# 3;TP_FAIXA_ETARIA_9;0,5044%
# 4;TP_FAIXA_ETARIA_9;0,0060%
# 0;TP_FAIXA_ETARIA_10;0,0205%
# 1;TP_FAIXA_ETARIA_10;0,9069%
# 2;TP_FAIXA_ETARIA_10;0,0391%
# 3;TP_FAIXA_ETARIA_10;0,3771%
# 4;TP_FAIXA_ETARIA_10;0,0047%
# 0;TP_FAIXA_ETARIA_11;0,0753%
# 1;TP_FAIXA_ETARIA_11;2,9730%
# 2;TP_FAIXA_ETARIA_11;0,0979%
# 3;TP_FAIXA_ETARIA_11;1,1125%
# 4;TP_FAIXA_ETARIA_11;0,0137%
# 0;TP_FAIXA_ETARIA_12;0,0500%
# 1;TP_FAIXA_ETARIA_12;1,5419%
# 2;TP_FAIXA_ETARIA_12;0,0463%
# 3;TP_FAIXA_ETARIA_12;0,6012%
# 4;TP_FAIXA_ETARIA_12;0,0090%
# 0;TP_FAIXA_ETARIA_13;0,1198%
# 1;TP_FAIXA_ETARIA_13;2,9071%
# 2;TP_FAIXA_ETARIA_13;0,1297%
# 3;TP_FAIXA_ETARIA_13;1,3103%
# 4;TP_FAIXA_ETARIA_13;0,0405%
# 0;TP_SEXO_F;9,3063%
# 1;TP_SEXO_F;20,5934%
# 2;TP_SEXO_F;7,1462%
# 3;TP_SEXO_F;13,6365%
# 4;TP_SEXO_F;10,7024%
# 0;TP_SEXO_M;5,0220%
# 1;TP_SEXO_M;10,3147%
# 2;TP_SEXO_M;6,0606%
# 3;TP_SEXO_M;9,2812%
# 4;TP_SEXO_M;7,9367%
# 0;TP_ESTADO_CIVIL_0;0,6237%
# 1;TP_ESTADO_CIVIL_0;1,2965%
# 2;TP_ESTADO_CIVIL_0;0,4533%
# 3;TP_ESTADO_CIVIL_0;0,8366%
# 4;TP_ESTADO_CIVIL_0;0,6794%
# 0;TP_ESTADO_CIVIL_1;13,4555%
# 1;TP_ESTADO_CIVIL_1;26,7770%
# 2;TP_ESTADO_CIVIL_1;12,5287%
# 3;TP_ESTADO_CIVIL_1;20,6591%
# 4;TP_ESTADO_CIVIL_1;17,7277%
# 0;TP_ESTADO_CIVIL_2;0,1393%
# 1;TP_ESTADO_CIVIL_2;2,1098%
# 2;TP_ESTADO_CIVIL_2;0,1343%
# 3;TP_ESTADO_CIVIL_2;1,1137%
# 4;TP_ESTADO_CIVIL_2;0,0886%
# 0;TP_ESTADO_CIVIL_3;0,1037%
# 1;TP_ESTADO_CIVIL_3;0,6691%
# 2;TP_ESTADO_CIVIL_3;0,0871%
# 3;TP_ESTADO_CIVIL_3;0,2852%
# 4;TP_ESTADO_CIVIL_3;0,1396%
# 0;TP_ESTADO_CIVIL_4;0,0062%
# 1;TP_ESTADO_CIVIL_4;0,0557%
# 2;TP_ESTADO_CIVIL_4;0,0034%
# 3;TP_ESTADO_CIVIL_4;0,0231%
# 4;TP_ESTADO_CIVIL_4;0,0037%
# 0;TP_COR_RACA_0;0,1962%
# 1;TP_COR_RACA_0;0,4117%
# 2;TP_COR_RACA_0;0,1376%
# 3;TP_COR_RACA_0;0,3096%
# 4;TP_COR_RACA_0;0,1856%
# 0;TP_COR_RACA_1;3,2419%
# 1;TP_COR_RACA_1;7,4905%
# 2;TP_COR_RACA_1;10,3484%
# 3;TP_COR_RACA_1;12,4716%
# 4;TP_COR_RACA_1;9,5270%
# 0;TP_COR_RACA_2;2,1428%
# 1;TP_COR_RACA_2;5,2434%
# 2;TP_COR_RACA_2;0,4139%
# 3;TP_COR_RACA_2;2,1027%
# 4;TP_COR_RACA_2;1,9330%
# 0;TP_COR_RACA_3;8,3776%
# 1;TP_COR_RACA_3;16,9733%
# 2;TP_COR_RACA_3;2,0340%
# 3;TP_COR_RACA_3;7,6494%
# 4;TP_COR_RACA_3;6,6803%
# 0;TP_COR_RACA_4;0,2347%
# 1;TP_COR_RACA_4;0,5275%
# 2;TP_COR_RACA_4;0,2590%
# 3;TP_COR_RACA_4;0,3268%
# 4;TP_COR_RACA_4;0,2453%
# 0;TP_COR_RACA_5;0,1350%
# 1;TP_COR_RACA_5;0,2617%
# 2;TP_COR_RACA_5;0,0139%
# 3;TP_COR_RACA_5;0,0575%
# 4;TP_COR_RACA_5;0,0678%
# 0;TP_NACIONALIDADE_0;0,0129%
# 1;TP_NACIONALIDADE_0;0,0126%
# 2;TP_NACIONALIDADE_0;0,0047%
# 3;TP_NACIONALIDADE_0;0,0069%
# 4;TP_NACIONALIDADE_0;0,0093%
# 0;TP_NACIONALIDADE_1;13,9285%
# 1;TP_NACIONALIDADE_1;30,1344%
# 2;TP_NACIONALIDADE_1;13,0221%
# 3;TP_NACIONALIDADE_1;22,4936%
# 4;TP_NACIONALIDADE_1;18,1857%
# 0;TP_NACIONALIDADE_2;0,3420%
# 1;TP_NACIONALIDADE_2;0,6804%
# 2;TP_NACIONALIDADE_2;0,1019%
# 3;TP_NACIONALIDADE_2;0,3072%
# 4;TP_NACIONALIDADE_2;0,3459%
# 0;TP_NACIONALIDADE_3;0,0242%
# 1;TP_NACIONALIDADE_3;0,0471%
# 2;TP_NACIONALIDADE_3;0,0212%
# 3;TP_NACIONALIDADE_3;0,0394%
# 4;TP_NACIONALIDADE_3;0,0432%
# 0;TP_NACIONALIDADE_4;0,0206%
# 1;TP_NACIONALIDADE_4;0,0336%
# 2;TP_NACIONALIDADE_4;0,0569%
# 3;TP_NACIONALIDADE_4;0,0705%
# 4;TP_NACIONALIDADE_4;0,0550%
# 0;TP_ST_CONCLUSAO_1;0,0000%
# 1;TP_ST_CONCLUSAO_1;24,3398%
# 2;TP_ST_CONCLUSAO_1;2,4334%
# 3;TP_ST_CONCLUSAO_1;14,5215%
# 4;TP_ST_CONCLUSAO_1;0,0000%
# 0;TP_ST_CONCLUSAO_2;14,3283%
# 1;TP_ST_CONCLUSAO_2;0,0001%
# 2;TP_ST_CONCLUSAO_2;6,0517%
# 3;TP_ST_CONCLUSAO_2;0,2176%
# 4;TP_ST_CONCLUSAO_2;18,6390%
# 0;TP_ST_CONCLUSAO_3;0,0000%
# 1;TP_ST_CONCLUSAO_3;6,4296%
# 2;TP_ST_CONCLUSAO_3;4,6257%
# 3;TP_ST_CONCLUSAO_3;8,0398%
# 4;TP_ST_CONCLUSAO_3;0,0001%
# 0;TP_ST_CONCLUSAO_4;0,0000%
# 1;TP_ST_CONCLUSAO_4;0,1386%
# 2;TP_ST_CONCLUSAO_4;0,0960%
# 3;TP_ST_CONCLUSAO_4;0,1387%
# 4;TP_ST_CONCLUSAO_4;0,0000%
# 0;TP_ESCOLA_1;0,0000%
# 1;TP_ESCOLA_1;30,9080%
# 2;TP_ESCOLA_1;7,1552%
# 3;TP_ESCOLA_1;22,7002%
# 4;TP_ESCOLA_1;0,0001%
# 0;TP_ESCOLA_2;13,8936%
# 1;TP_ESCOLA_2;0,0000%
# 2;TP_ESCOLA_2;1,4168%
# 3;TP_ESCOLA_2;0,0007%
# 4;TP_ESCOLA_2;15,6616%
# 0;TP_ESCOLA_3;0,4348%
# 1;TP_ESCOLA_3;0,0001%
# 2;TP_ESCOLA_3;4,6349%
# 3;TP_ESCOLA_3;0,2168%
# 4;TP_ESCOLA_3;2,9773%
# 0;Q001_A;0,8954%
# 1;Q001_A;2,2692%
# 2;Q001_A;0,0138%
# 3;Q001_A;0,2550%
# 4;Q001_A;0,1637%
# 0;Q001_B;3,2655%
# 1;Q001_B;8,3830%
# 2;Q001_B;0,1480%
# 3;Q001_B;1,9258%
# 4;Q001_B;1,5886%
# 0;Q001_C;2,3384%
# 1;Q001_C;4,8423%
# 2;Q001_C;0,3677%
# 3;Q001_C;2,5257%
# 4;Q001_C;2,3008%
# 0;Q001_D;1,9338%
# 1;Q001_D;3,5019%
# 2;Q001_D;0,5993%
# 3;Q001_D;2,5297%
# 4;Q001_D;2,5331%
# 0;Q001_E;3,2323%
# 1;Q001_E;7,1878%
# 2;Q001_E;2,8753%
# 3;Q001_E;9,2800%
# 4;Q001_E;7,6373%
# 0;Q001_F;0,3323%
# 1;Q001_F;0,9335%
# 2;Q001_F;3,8964%
# 3;Q001_F;3,1667%
# 4;Q001_F;1,7449%
# 0;Q001_G;0,1504%
# 1;Q001_G;0,3940%
# 2;Q001_G;4,8907%
# 3;Q001_G;1,7220%
# 4;Q001_G;0,8558%
# 0;Q001_H;2,1801%
# 1;Q001_H;3,3965%
# 2;Q001_H;0,4155%
# 3;Q001_H;1,5128%
# 4;Q001_H;1,8149%
# 0;Q002_A;0,4662%
# 1;Q002_A;1,4261%
# 2;Q002_A;0,0076%
# 3;Q002_A;0,1797%
# 4;Q002_A;0,0774%
# 0;Q002_B;2,2296%
# 1;Q002_B;6,1447%
# 2;Q002_B;0,0661%
# 3;Q002_B;1,1765%
# 4;Q002_B;0,8518%
# 0;Q002_C;2,1781%
# 1;Q002_C;4,4430%
# 2;Q002_C;0,1559%
# 3;Q002_C;1,6414%
# 4;Q002_C;1,5010%
# 0;Q002_D;2,4048%
# 1;Q002_D;4,2321%
# 2;Q002_D;0,3358%
# 3;Q002_D;2,1036%
# 4;Q002_D;2,2726%
# 0;Q002_E;5,0325%
# 1;Q002_E;10,7194%
# 2;Q002_E;2,3743%
# 3;Q002_E;9,4711%
# 4;Q002_E;8,6555%
# 0;Q002_F;0,7544%
# 1;Q002_F;1,8951%
# 2;Q002_F;4,0564%
# 3;Q002_F;4,1353%
# 4;Q002_F;2,5711%
# 0;Q002_G;0,4355%
# 1;Q002_G;1,1852%
# 2;Q002_G;6,0306%
# 3;Q002_G;3,7822%
# 4;Q002_G;2,1158%
# 0;Q002_H;0,8272%
# 1;Q002_H;0,8625%
# 2;Q002_H;0,1801%
# 3;Q002_H;0,4279%
# 4;Q002_H;0,5939%
# 0;Q003_A;4,5953%
# 1;Q003_A;9,6169%
# 2;Q003_A;0,2728%
# 3;Q003_A;1,5786%
# 4;Q003_A;1,4272%
# 0;Q003_B;3,4088%
# 1;Q003_B;7,5389%
# 2;Q003_B;0,4761%
# 3;Q003_B;3,8022%
# 4;Q003_B;3,6851%
# 0;Q003_C;2,9123%
# 1;Q003_C;6,7976%
# 2;Q003_C;0,8265%
# 3;Q003_C;6,2380%
# 4;Q003_C;6,0381%
# 0;Q003_D;0,8968%
# 1;Q003_D;2,3908%
# 2;Q003_D;5,3697%
# 3;Q003_D;7,5959%
# 4;Q003_D;4,4107%
# 0;Q003_E;0,0849%
# 1;Q003_E;0,2630%
# 2;Q003_E;5,6537%
# 3;Q003_E;1,4811%
# 4;Q003_E;0,7160%
# 0;Q003_F;2,4302%
# 1;Q003_F;4,3009%
# 2;Q003_F;0,6079%
# 3;Q003_F;2,2220%
# 4;Q003_F;2,3622%
# 0;Q004_A;3,9662%
# 1;Q004_A;8,2603%
# 2;Q004_A;0,0998%
# 3;Q004_A;0,9004%
# 4;Q004_A;0,7802%
# 0;Q004_B;6,6086%
# 1;Q004_B;14,8766%
# 2;Q004_B;1,1171%
# 3;Q004_B;8,3050%
# 4;Q004_B;8,2022%
# 0;Q004_C;0,7919%
# 1;Q004_C;1,6828%
# 2;Q004_C;0,2860%
# 3;Q004_C;1,6660%
# 4;Q004_C;1,6718%
# 0;Q004_D;1,3456%
# 1;Q004_D;3,4876%
# 2;Q004_D;6,5881%
# 3;Q004_D;9,0242%
# 4;Q004_D;5,5478%
# 0;Q004_E;0,0677%
# 1;Q004_E;0,1783%
# 2;Q004_E;4,2410%
# 3;Q004_E;1,0919%
# 4;Q004_E;0,5606%
# 0;Q004_F;1,5483%
# 1;Q004_F;2,4226%
# 2;Q004_F;0,8749%
# 3;Q004_F;1,9301%
# 4;Q004_F;1,8766%
# 0;Q005_1;0,1288%
# 1;Q005_1;2,1104%
# 2;Q005_1;0,0257%
# 3;Q005_1;0,3967%
# 4;Q005_1;0,0414%
# 0;Q005_2;1,7807%
# 1;Q005_2;5,6377%
# 2;Q005_2;0,7165%
# 3;Q005_2;2,9566%
# 4;Q005_2;1,9788%
# 0;Q005_3;3,6219%
# 1;Q005_3;7,8412%
# 2;Q005_3;3,4950%
# 3;Q005_3;7,4698%
# 4;Q005_3;5,8247%
# 0;Q005_4;4,4493%
# 1;Q005_4;8,1249%
# 2;Q005_4;6,4533%
# 3;Q005_4;7,9825%
# 4;Q005_4;6,7426%
# 0;Q005_5;4,3476%
# 1;Q005_5;7,1940%
# 2;Q005_5;2,5162%
# 3;Q005_5;4,1121%
# 4;Q005_5;4,0516%
# 0;Q006_A;1,8056%
# 1;Q006_A;3,5051%
# 2;Q006_A;0,0346%
# 3;Q006_A;0,1904%
# 4;Q006_A;0,2740%
# 0;Q006_B;8,9505%
# 1;Q006_B;15,7397%
# 2;Q006_B;0,0625%
# 3;Q006_B;1,7090%
# 4;Q006_B;2,6285%
# 0;Q006_C;2,1868%
# 1;Q006_C;6,2772%
# 2;Q006_C;0,1284%
# 3;Q006_C;3,1755%
# 4;Q006_C;3,7065%
# 0;Q006_D;0,8098%
# 1;Q006_D;2,8905%
# 2;Q006_D;0,2635%
# 3;Q006_D;3,6907%
# 4;Q006_D;3,3929%
# 0;Q006_E;0,3028%
# 1;Q006_E;1,2141%
# 2;Q006_E;0,4282%
# 3;Q006_E;3,2827%
# 4;Q006_E;2,5951%
# 0;Q006_F;0,1168%
# 1;Q006_F;0,5009%
# 2;Q006_F;0,4379%
# 3;Q006_F;2,1385%
# 4;Q006_F;1,5555%
# 0;Q006_G;0,0983%
# 1;Q006_G;0,4665%
# 2;Q006_G;1,2091%
# 3;Q006_G;3,5745%
# 4;Q006_G;2,1831%
# 0;Q006_H;0,0284%
# 1;Q006_H;0,1467%
# 2;Q006_H;1,1914%
# 3;Q006_H;1,8090%
# 4;Q006_H;0,9477%
# 0;Q006_I;0,0132%
# 1;Q006_I;0,0655%
# 2;Q006_I;0,9414%
# 3;Q006_I;1,0696%
# 4;Q006_I;0,5027%
# 0;Q006_J;0,0078%
# 1;Q006_J;0,0394%
# 2;Q006_J;1,0579%
# 3;Q006_J;0,8412%
# 4;Q006_J;0,3569%
# 0;Q006_K;0,0028%
# 1;Q006_K;0,0230%
# 2;Q006_K;1,0564%
# 3;Q006_K;0,5477%
# 4;Q006_K;0,2108%
# 0;Q006_L;0,0056%
# 1;Q006_L;0,0394%
# 2;Q006_L;6,3956%
# 3;Q006_L;0,8889%
# 4;Q006_L;0,2854%
# 0;Q007_A;13,8486%
# 1;Q007_A;30,1358%
# 2;Q007_A;7,0641%
# 3;Q007_A;21,8021%
# 4;Q007_A;17,9769%
# 0;Q007_B;0,2649%
# 1;Q007_B;0,4529%
# 2;Q007_B;3,3046%
# 3;Q007_B;0,6804%
# 4;Q007_B;0,3500%
# 0;Q007_C;0,0681%
# 1;Q007_C;0,1041%
# 2;Q007_C;0,6957%
# 3;Q007_C;0,1488%
# 4;Q007_C;0,1011%
# 0;Q007_D;0,1467%
# 1;Q007_D;0,2153%
# 2;Q007_D;2,1424%
# 3;Q007_D;0,2864%
# 4;Q007_D;0,2111%
# 0;Q008_A;0,3479%
# 1;Q008_A;0,4576%
# 2;Q008_A;0,0040%
# 3;Q008_A;0,0146%
# 4;Q008_A;0,0189%
# 0;Q008_B;13,0302%
# 1;Q008_B;28,1468%
# 2;Q008_B;0,6979%
# 3;Q008_B;10,1338%
# 4;Q008_B;11,0940%
# 0;Q008_C;0,8923%
# 1;Q008_C;2,1583%
# 2;Q008_C;4,1611%
# 3;Q008_C;10,4063%
# 4;Q008_C;6,3700%
# 0;Q008_D;0,0512%
# 1;Q008_D;0,1294%
# 2;Q008_D;4,5540%
# 3;Q008_D;1,9809%
# 4;Q008_D;0,9924%
# 0;Q008_E;0,0066%
# 1;Q008_E;0,0160%
# 2;Q008_E;3,7899%
# 3;Q008_E;0,3820%
# 4;Q008_E;0,1638%
# 0;Q009_A;0,2263%
# 1;Q009_A;0,4323%
# 2;Q009_A;0,0019%
# 3;Q009_A;0,0252%
# 4;Q009_A;0,0293%
# 0;Q009_B;2,9617%
# 1;Q009_B;7,1218%
# 2;Q009_B;0,0281%
# 3;Q009_B;0,8578%
# 4;Q009_B;0,8049%
# 0;Q009_C;8,7154%
# 1;Q009_C;18,3644%
# 2;Q009_C;1,6509%
# 3;Q009_C;10,5342%
# 4;Q009_C;9,9722%
# 0;Q009_D;2,2059%
# 1;Q009_D;4,5836%
# 2;Q009_D;8,3606%
# 3;Q009_D;10,3110%
# 4;Q009_D;7,0229%
# 0;Q009_E;0,2191%
# 1;Q009_E;0,4060%
# 2;Q009_E;3,1653%
# 3;Q009_E;1,1895%
# 4;Q009_E;0,8098%
# 0;Q010_A;12,7420%
# 1;Q010_A;26,5919%
# 2;Q010_A;0,4190%
# 3;Q010_A;5,0565%
# 4;Q010_A;5,4243%
# 0;Q010_B;1,5425%
# 1;Q010_B;4,1910%
# 2;Q010_B;5,5490%
# 3;Q010_B;15,5108%
# 4;Q010_B;11,7176%
# 0;Q010_C;0,0393%
# 1;Q010_C;0,1160%
# 2;Q010_C;6,1082%
# 3;Q010_C;2,1503%
# 4;Q010_C;1,3604%
# 0;Q010_D;0,0033%
# 1;Q010_D;0,0074%
# 2;Q010_D;0,9132%
# 3;Q010_D;0,1732%
# 4;Q010_D;0,1164%
# 0;Q010_E;0,0012%
# 1;Q010_E;0,0020%
# 2;Q010_E;0,2174%
# 3;Q010_E;0,0268%
# 4;Q010_E;0,0203%
# 0;Q011_A;10,5906%
# 1;Q011_A;23,5101%
# 2;Q011_A;10,9095%
# 3;Q011_A;16,6995%
# 4;Q011_A;13,3860%
# 0;Q011_B;3,4590%
# 1;Q011_B;6,8858%
# 2;Q011_B;1,8581%
# 3;Q011_B;5,3245%
# 4;Q011_B;4,5141%
# 0;Q011_C;0,2582%
# 1;Q011_C;0,4820%
# 2;Q011_C;0,3502%
# 3;Q011_C;0,8055%
# 4;Q011_C;0,6632%
# 0;Q011_D;0,0187%
# 1;Q011_D;0,0278%
# 2;Q011_D;0,0650%
# 3;Q011_D;0,0771%
# 4;Q011_D;0,0656%
# 0;Q011_E;0,0018%
# 1;Q011_E;0,0024%
# 2;Q011_E;0,0240%
# 3;Q011_E;0,0111%
# 4;Q011_E;0,0103%
# 0;Q012_A;0,5687%
# 1;Q012_A;0,9766%
# 2;Q012_A;0,0060%
# 3;Q012_A;0,0432%
# 4;Q012_A;0,0467%
# 0;Q012_B;13,6554%
# 1;Q012_B;29,7516%
# 2;Q012_B;9,5925%
# 3;Q012_B;21,7710%
# 4;Q012_B;17,7293%
# 0;Q012_C;0,1004%
# 1;Q012_C;0,1736%
# 2;Q012_C;3,2001%
# 3;Q012_C;1,0582%
# 4;Q012_C;0,8173%
# 0;Q012_D;0,0031%
# 1;Q012_D;0,0050%
# 2;Q012_D;0,3349%
# 3;Q012_D;0,0396%
# 4;Q012_D;0,0397%
# 0;Q012_E;0,0007%
# 1;Q012_E;0,0012%
# 2;Q012_E;0,0733%
# 3;Q012_E;0,0056%
# 4;Q012_E;0,0061%
# 0;Q013_A;11,9604%
# 1;Q013_A;24,5024%
# 2;Q013_A;1,9663%
# 3;Q013_A;7,7663%
# 4;Q013_A;6,8475%
# 0;Q013_B;2,3300%
# 1;Q013_B;6,3313%
# 2;Q013_B;8,6146%
# 3;Q013_B;14,4203%
# 4;Q013_B;11,2057%
# 0;Q013_C;0,0347%
# 1;Q013_C;0,0675%
# 2;Q013_C;2,2243%
# 3;Q013_C;0,6579%
# 4;Q013_C;0,5204%
# 0;Q013_D;0,0025%
# 1;Q013_D;0,0052%
# 2;Q013_D;0,3317%
# 3;Q013_D;0,0593%
# 4;Q013_D;0,0521%
# 0;Q013_E;0,0008%
# 1;Q013_E;0,0018%
# 2;Q013_E;0,0699%
# 3;Q013_E;0,0139%
# 4;Q013_E;0,0135%
# 0;Q014_A;11,1956%
# 1;Q014_A;21,3241%
# 2;Q014_A;0,1487%
# 3;Q014_A;1,6966%
# 4;Q014_A;1,6736%
# 0;Q014_B;3,1114%
# 1;Q014_B;9,5545%
# 2;Q014_B;12,3402%
# 3;Q014_B;20,9615%
# 4;Q014_B;16,6916%
# 0;Q014_C;0,0206%
# 1;Q014_C;0,0283%
# 2;Q014_C;0,6806%
# 3;Q014_C;0,2511%
# 4;Q014_C;0,2639%
# 0;Q014_D;0,0006%
# 1;Q014_D;0,0009%
# 2;Q014_D;0,0302%
# 3;Q014_D;0,0068%
# 4;Q014_D;0,0088%
# 0;Q014_E;0,0001%
# 1;Q014_E;0,0004%
# 2;Q014_E;0,0070%
# 3;Q014_E;0,0017%
# 4;Q014_E;0,0012%
# 0;Q015_A;13,9770%
# 1;Q015_A;29,9317%
# 2;Q015_A;7,9184%
# 3;Q015_A;19,2086%
# 4;Q015_A;15,5760%
# 0;Q015_B;0,3490%
# 1;Q015_B;0,9725%
# 2;Q015_B;5,1743%
# 3;Q015_B;3,6812%
# 4;Q015_B;3,0312%
# 0;Q015_C;0,0019%
# 1;Q015_C;0,0031%
# 2;Q015_C;0,1019%
# 3;Q015_C;0,0255%
# 4;Q015_C;0,0299%
# 0;Q015_D;0,0002%
# 1;Q015_D;0,0004%
# 2;Q015_D;0,0079%
# 3;Q015_D;0,0014%
# 4;Q015_D;0,0016%
# 0;Q015_E;0,0002%
# 1;Q015_E;0,0004%
# 2;Q015_E;0,0043%
# 3;Q015_E;0,0010%
# 4;Q015_E;0,0003%
# 0;Q016_A;12,6236%
# 1;Q016_A;25,2882%
# 2;Q016_A;0,8149%
# 3;Q016_A;5,3622%
# 4;Q016_A;5,3543%
# 0;Q016_B;1,6993%
# 1;Q016_B;5,6118%
# 2;Q016_B;11,7819%
# 3;Q016_B;17,4379%
# 4;Q016_B;13,1657%
# 0;Q016_C;0,0048%
# 1;Q016_C;0,0072%
# 2;Q016_C;0,5689%
# 3;Q016_C;0,1131%
# 4;Q016_C;0,1138%
# 0;Q016_D;0,0003%
# 1;Q016_D;0,0005%
# 2;Q016_D;0,0322%
# 3;Q016_D;0,0035%
# 4;Q016_D;0,0039%
# 0;Q016_E;0,0003%
# 1;Q016_E;0,0003%
# 2;Q016_E;0,0089%
# 3;Q016_E;0,0009%
# 4;Q016_E;0,0013%
# 0;Q017_A;14,2576%
# 1;Q017_A;30,7787%
# 2;Q017_A;10,4124%
# 3;Q017_A;22,4317%
# 4;Q017_A;18,3265%
# 0;Q017_B;0,0698%
# 1;Q017_B;0,1273%
# 2;Q017_B;2,7381%
# 3;Q017_B;0,4805%
# 4;Q017_B;0,3063%
# 0;Q017_C;0,0006%
# 1;Q017_C;0,0010%
# 2;Q017_C;0,0479%
# 3;Q017_C;0,0041%
# 4;Q017_C;0,0053%
# 0;Q017_D;0,0001%
# 1;Q017_D;0,0005%
# 2;Q017_D;0,0044%
# 3;Q017_D;0,0006%
# 4;Q017_D;0,0006%
# 0;Q017_E;0,0002%
# 1;Q017_E;0,0006%
# 2;Q017_E;0,0040%
# 3;Q017_E;0,0007%
# 4;Q017_E;0,0003%
# 0;Q018_A;14,1886%
# 1;Q018_A;30,2927%
# 2;Q018_A;2,0377%
# 3;Q018_A;14,4582%
# 4;Q018_A;13,1176%
# 0;Q018_B;0,1397%
# 1;Q018_B;0,6154%
# 2;Q018_B;11,1691%
# 3;Q018_B;8,4595%
# 4;Q018_B;5,5215%
# 0;Q019_A;1,8545%
# 1;Q019_A;3,7987%
# 2;Q019_A;0,0456%
# 3;Q019_A;0,5974%
# 4;Q019_A;0,5448%
# 0;Q019_B;11,9717%
# 1;Q019_B;25,7522%
# 2;Q019_B;1,7087%
# 3;Q019_B;12,5589%
# 4;Q019_B;11,8904%
# 0;Q019_C;0,4644%
# 1;Q019_C;1,2582%
# 2;Q019_C;4,4264%
# 3;Q019_C;7,4816%
# 4;Q019_C;4,8113%
# 0;Q019_D;0,0337%
# 1;Q019_D;0,0899%
# 2;Q019_D;3,9610%
# 3;Q019_D;1,9187%
# 4;Q019_D;1,1883%
# 0;Q019_E;0,0040%
# 1;Q019_E;0,0092%
# 2;Q019_E;3,0651%
# 3;Q019_E;0,3611%
# 4;Q019_E;0,2043%
# 0;Q020_A;13,3640%
# 1;Q020_A;29,0692%
# 2;Q020_A;7,6211%
# 3;Q020_A;19,6914%
# 4;Q020_A;16,1036%
# 0;Q020_B;0,9643%
# 1;Q020_B;1,8390%
# 2;Q020_B;5,5857%
# 3;Q020_B;3,2263%
# 4;Q020_B;2,5354%
# 0;Q021_A;13,5524%
# 1;Q021_A;29,2972%
# 2;Q021_A;3,2657%
# 3;Q021_A;16,4903%
# 4;Q021_A;13,9517%
# 0;Q021_B;0,7760%
# 1;Q021_B;1,6109%
# 2;Q021_B;9,9411%
# 3;Q021_B;6,4274%
# 4;Q021_B;4,6874%
# 0;Q022_A;0,6241%
# 1;Q022_A;0,8810%
# 2;Q022_A;0,1581%
# 3;Q022_A;0,3176%
# 4;Q022_A;0,3925%
# 0;Q022_B;4,3870%
# 1;Q022_B;9,6073%
# 2;Q022_B;0,2497%
# 3;Q022_B;1,1851%
# 4;Q022_B;1,0945%
# 0;Q022_C;5,4156%
# 1;Q022_C;11,7643%
# 2;Q022_C;0,7426%
# 3;Q022_C;4,6222%
# 4;Q022_C;3,6960%
# 0;Q022_D;2,8210%
# 1;Q022_D;6,3335%
# 2;Q022_D;3,9255%
# 3;Q022_D;9,8860%
# 4;Q022_D;8,0687%
# 0;Q022_E;1,0806%
# 1;Q022_E;2,3220%
# 2;Q022_E;8,1309%
# 3;Q022_E;6,9068%
# 4;Q022_E;5,3874%
# 0;Q023_A;14,0341%
# 1;Q023_A;30,0632%
# 2;Q023_A;9,1460%
# 3;Q023_A;19,9764%
# 4;Q023_A;16,6873%
# 0;Q023_B;0,2942%
# 1;Q023_B;0,8449%
# 2;Q023_B;4,0608%
# 3;Q023_B;2,9412%
# 4;Q023_B;1,9518%
# 0;Q024_A;12,8512%
# 1;Q024_A;23,2239%
# 2;Q024_A;0,4782%
# 3;Q024_A;4,5220%
# 4;Q024_A;6,8567%
# 0;Q024_B;1,4133%
# 1;Q024_B;7,2687%
# 2;Q024_B;3,3898%
# 3;Q024_B;14,1600%
# 4;Q024_B;9,8951%
# 0;Q024_C;0,0578%
# 1;Q024_C;0,3752%
# 2;Q024_C;4,6871%
# 3;Q024_C;3,3974%
# 4;Q024_C;1,5568%
# 0;Q024_D;0,0053%
# 1;Q024_D;0,0342%
# 2;Q024_D;2,9062%
# 3;Q024_D;0,6926%
# 4;Q024_D;0,2756%
# 0;Q024_E;0,0007%
# 1;Q024_E;0,0061%
# 2;Q024_E;1,7455%
# 3;Q024_E;0,1457%
# 4;Q024_E;0,0549%
# 0;Q025_A;2,9499%
# 1;Q025_A;4,9762%
# 2;Q025_A;0,0109%
# 3;Q025_A;0,1421%
# 4;Q025_A;0,2255%
# 0;Q025_B;11,3785%
# 1;Q025_B;25,9319%
# 2;Q025_B;13,1959%
# 3;Q025_B;22,7756%
# 4;Q025_B;18,4136%
# 0;MACRO_REGIAO_CENTRO_OESTE;0,8277%
# 1;MACRO_REGIAO_CENTRO_OESTE;1,6334%
# 2;MACRO_REGIAO_CENTRO_OESTE;1,3882%
# 3;MACRO_REGIAO_CENTRO_OESTE;2,1806%
# 4;MACRO_REGIAO_CENTRO_OESTE;2,1597%
# 0;MACRO_REGIAO_NORDESTE;8,9297%
# 1;MACRO_REGIAO_NORDESTE;17,2601%
# 2;MACRO_REGIAO_NORDESTE;2,1721%
# 3;MACRO_REGIAO_NORDESTE;5,4720%
# 4;MACRO_REGIAO_NORDESTE;3,2171%
# 0;MACRO_REGIAO_NORTE;2,1623%
# 1;MACRO_REGIAO_NORTE;4,9323%
# 2;MACRO_REGIAO_NORTE;0,5768%
# 3;MACRO_REGIAO_NORTE;1,6264%
# 4;MACRO_REGIAO_NORTE;1,3495%
# 0;MACRO_REGIAO_SUDESTE;1,9621%
# 1;MACRO_REGIAO_SUDESTE;5,8276%
# 2;MACRO_REGIAO_SUDESTE;6,6596%
# 3;MACRO_REGIAO_SUDESTE;10,3859%
# 4;MACRO_REGIAO_SUDESTE;8,5160%
# 0;MACRO_REGIAO_SUL;0,4466%
# 1;MACRO_REGIAO_SUL;1,2547%
# 2;MACRO_REGIAO_SUL;2,4101%
# 3;MACRO_REGIAO_SUL;3,2528%
# 4;MACRO_REGIAO_SUL;3,3969%
# All;MEDIA_NOTAS;540,6086
# All;TP_FAIXA_ETARIA_1;10,7725%
# All;TP_FAIXA_ETARIA_2;23,1791%
# All;TP_FAIXA_ETARIA_3;25,4951%
# All;TP_FAIXA_ETARIA_4;10,9149%
# All;TP_FAIXA_ETARIA_5;6,3235%
# All;TP_FAIXA_ETARIA_6;4,0599%
# All;TP_FAIXA_ETARIA_7;2,9054%
# All;TP_FAIXA_ETARIA_8;2,2298%
# All;TP_FAIXA_ETARIA_9;1,7433%
# All;TP_FAIXA_ETARIA_10;1,3483%
# All;TP_FAIXA_ETARIA_11;4,2724%
# All;TP_FAIXA_ETARIA_12;2,2485%
# All;TP_FAIXA_ETARIA_13;4,5074%
# All;TP_SEXO_F;61,3848%
# All;TP_SEXO_M;38,6152%
# All;TP_ESTADO_CIVIL_0;3,8895%
# All;TP_ESTADO_CIVIL_1;91,1480%
# All;TP_ESTADO_CIVIL_2;3,5858%
# All;TP_ESTADO_CIVIL_3;1,2848%
# All;TP_ESTADO_CIVIL_4;0,0920%
# All;TP_COR_RACA_0;1,2407%
# All;TP_COR_RACA_1;43,0795%
# All;TP_COR_RACA_2;11,8359%
# All;TP_COR_RACA_3;41,7146%
# All;TP_COR_RACA_4;1,5933%
# All;TP_COR_RACA_5;0,5359%
# All;TP_NACIONALIDADE_0;0,0464%
# All;TP_NACIONALIDADE_1;97,7643%
# All;TP_NACIONALIDADE_2;1,7775%
# All;TP_NACIONALIDADE_3;0,1751%
# All;TP_NACIONALIDADE_4;0,2366%
# All;TP_ST_CONCLUSAO_1;41,2947%
# All;TP_ST_CONCLUSAO_2;39,2367%
# All;TP_ST_CONCLUSAO_3;19,0952%
# All;TP_ST_CONCLUSAO_4;0,3733%
# All;TP_ESCOLA_1;60,7635%
# All;TP_ESCOLA_2;30,9727%
# All;TP_ESCOLA_3;8,2639%
# All;Q001_A;3,5971%
# All;Q001_B;15,3109%
# All;Q001_C;12,3748%
# All;Q001_D;11,0980%
# All;Q001_E;30,2126%
# All;Q001_F;10,0738%
# All;Q001_G;8,0130%
# All;Q001_H;9,3199%
# All;Q002_A;2,1570%
# All;Q002_B;10,4686%
# All;Q002_C;9,9193%
# All;Q002_D;11,3490%
# All;Q002_E;36,2528%
# All;Q002_F;13,4123%
# All;Q002_G;13,5493%
# All;Q002_H;2,8915%
# All;Q003_A;17,4908%
# All;Q003_B;18,9111%
# All;Q003_C;22,8125%
# All;Q003_D;20,6639%
# All;Q003_E;8,1987%
# All;Q003_F;11,9232%
# All;Q004_A;14,0068%
# All;Q004_B;39,1095%
# All;Q004_C;6,0983%
# All;Q004_D;25,9934%
# All;Q004_E;6,1396%
# All;Q004_F;8,6524%
# All;Q005_1;2,7031%
# All;Q005_2;13,0704%
# All;Q005_3;28,2526%
# All;Q005_4;33,7525%
# All;Q005_5;22,2214%
# All;Q006_A;5,8097%
# All;Q006_B;29,0901%
# All;Q006_C;15,4744%
# All;Q006_D;11,0473%
# All;Q006_E;7,8228%
# All;Q006_F;4,7496%
# All;Q006_G;7,5315%
# All;Q006_H;4,1233%
# All;Q006_I;2,5924%
# All;Q006_J;2,3032%
# All;Q006_K;1,8406%
# All;Q006_L;7,6150%
# All;Q007_A;90,8275%
# All;Q007_B;5,0528%
# All;Q007_C;1,1179%
# All;Q007_D;3,0018%
# All;Q008_A;0,8431%
# All;Q008_B;63,1027%
# All;Q008_C;23,9880%
# All;Q008_D;7,7078%
# All;Q008_E;4,3584%
# All;Q009_A;0,7149%
# All;Q009_B;11,7743%
# All;Q009_C;49,2372%
# All;Q009_D;32,4840%
# All;Q009_E;5,7896%
# All;Q010_A;50,2337%
# All;Q010_B;38,5110%
# All;Q010_C;9,7742%
# All;Q010_D;1,2135%
# All;Q010_E;0,2676%
# All;Q011_A;75,0958%
# All;Q011_B;22,0415%
# All;Q011_C;2,5591%
# All;Q011_D;0,2541%
# All;Q011_E;0,0495%
# All;Q012_A;1,6412%
# All;Q012_B;92,4999%
# All;Q012_C;5,3496%
# All;Q012_D;0,4223%
# All;Q012_E;0,0870%
# All;Q013_A;53,0428%
# All;Q013_B;42,9019%
# All;Q013_C;3,5048%
# All;Q013_D;0,4506%
# All;Q013_E;0,0998%
# All;Q014_A;36,0386%
# All;Q014_B;62,6591%
# All;Q014_C;1,2445%
# All;Q014_D;0,0473%
# All;Q014_E;0,0104%
# All;Q015_A;86,6117%
# All;Q015_B;13,2082%
# All;Q015_C;0,1622%
# All;Q015_D;0,0116%
# All;Q015_E;0,0062%
# All;Q016_A;49,4432%
# All;Q016_B;49,6966%
# All;Q016_C;0,8078%
# All;Q016_D;0,0405%
# All;Q016_E;0,0118%
# All;Q017_A;96,2070%
# All;Q017_B;3,7221%
# All;Q017_C;0,0588%
# All;Q017_D;0,0063%
# All;Q017_E;0,0058%
# All;Q018_A;74,0948%
# All;Q018_B;25,9052%
# All;Q019_A;6,8410%
# All;Q019_B;63,8819%
# All;Q019_C;18,4419%
# All;Q019_D;7,1915%
# All;Q019_E;3,6437%
# All;Q020_A;85,8493%
# All;Q020_B;14,1507%
# All;Q021_A;76,5572%
# All;Q021_B;23,4428%
# All;Q022_A;2,3733%
# All;Q022_B;16,5236%
# All;Q022_C;26,2408%
# All;Q022_D;31,0347%
# All;Q022_E;23,8277%
# All;Q023_A;89,9070%
# All;Q023_B;10,0930%
# All;Q024_A;47,9321%
# All;Q024_B;36,1269%
# All;Q024_C;10,0742%
# All;Q024_D;3,9140%
# All;Q024_E;1,9528%
# All;Q025_A;8,3046%
# All;Q025_B;91,6954%
# All;MACRO_REGIAO_CENTRO_OESTE;8,1896%
# All;MACRO_REGIAO_NORDESTE;37,0510%
# All;MACRO_REGIAO_NORTE;10,6472%
# All;MACRO_REGIAO_SUDESTE;33,3512%
# All;MACRO_REGIAO_SUL;10,7611%

# %%
from sklearn.feature_selection import chi2

colunas_para_selecao = [col for col in microdadosEnem.columns if col != 'MEDIA_NOTAS' and col != 'K_Cluster']

for cluster in np.sort(microdadosEnem.K_Cluster.unique()):
    
    # Criar a coluna de labels binários (1 se é do cluster atual, 0 caso contrário)
    labels_binarias = (microdadosEnem['K_Cluster'] == cluster).astype(int)
    
    # Calcular estatística Chi-Quadrado
    chi2_results = chi2(microdadosEnem[colunas_para_selecao].values, labels_binarias)
    chi2_scores = chi2_results[0]
    p_values = chi2_results[1]
    
    # Definir limites mais rigorosos de relevância e significância estatística
    thresh = 80000 # Testes anteriores feitos com: (1gl) 3.84; (2gl) 5.99 (4gl) 10.83 (6gl) 12.59 (7gl) 14.07
    pval_thresh = 0.01 # Testes anteriores feitos com: (default) 0.05 (rigoroso) 0.01
    
    # Selecionar características relevantes e estatisticamente significativas
    mask = (chi2_scores >= thresh) & (p_values <= pval_thresh)
    relevant_features = pd.Index(colunas_para_selecao)[mask]
    relevant_scores = chi2_scores[mask]
    
    # Combinar características e suas pontuações em um DataFrame e ordenar
    relevant_df = pd.DataFrame({'Feature': relevant_features, 'Chi2 Score': relevant_scores})
    relevant_df = relevant_df.sort_values(by='Chi2 Score', ascending=False)
    
    # Exibir resultados para o cluster atual
    print()
    print(f"============ Características mais relevantes para o Cluster {cluster} ============")
    print()
    for _, row in relevant_df.iterrows():
        print(f"{cluster:d};{row['Feature']};{row['Chi2 Score']:.2f}")
# Out:
# ============ Características mais relevantes para o Cluster 0 ============
#
# 0;TP_ESCOLA_2;629837.99
# 0;TP_ST_CONCLUSAO_2;421503.06
# 0;TP_ESCOLA_1;272178.36
# 0;Q014_A;220269.34
# 0;TP_ST_CONCLUSAO_1;184971.72
# 0;Q006_B;171535.91
# 0;Q024_A;162962.31
# 0;Q016_A;135397.23
# 0;Q010_A;133515.31
# 0;Q016_B;129038.56
# 0;Q014_B;119842.60
# 0;TP_FAIXA_ETARIA_3;116379.78
# 0;Q018_B;107468.45
# 0;Q010_B;89537.97
# 0;TP_ST_CONCLUSAO_3;85533.50
# 0;Q024_B;85521.52
# 0;Q025_A;81376.45
#
# ============ Características mais relevantes para o Cluster 1 ============
#
# 1;TP_ST_CONCLUSAO_2;470089.93
# 1;TP_ST_CONCLUSAO_1;407007.54
# 1;TP_ESCOLA_2;371088.62
# 1;Q014_A;361018.76
# 1;Q010_A;305706.29
# 1;TP_ESCOLA_1;303549.61
# 1;Q018_B;264497.66
# 1;Q016_A;253973.76
# 1;Q016_B;239828.76
# 1;Q006_B;196347.88
# 1;Q010_B;193690.89
# 1;Q014_B;192712.14
# 1;Q024_A;185019.62
# 1;Q021_B;169864.19
# 1;Q013_A;155430.32
# 1;Q022_B;153709.98
# 1;Q008_B;148466.70
# 1;Q008_C;144430.56
# 1;Q013_B;140345.34
# 1;Q004_A;138367.52
# 1;TP_FAIXA_ETARIA_3;137501.90
# 1;Q019_C;134175.47
# 1;Q022_E;133844.06
# 1;Q009_B;129190.18
# 1;Q003_A;127137.38
# 1;Q009_D;114954.64
# 1;MACRO_REGIAO_NORDESTE;114198.75
# 1;Q001_B;109169.18
# 1;Q010_C;108288.42
# 1;Q002_B;101384.15
# 1;Q004_D;99734.69
# 1;TP_ESCOLA_3;99001.96
# 1;TP_COR_RACA_1;98765.81
# 1;Q003_D;96916.00
# 1;TP_FAIXA_ETARIA_2;94906.43
# 1;Q024_C;93365.00
# 1;Q018_A;92474.36
# 1;Q015_B;91834.74
# 1;Q006_L;88210.68
# 1;Q025_A;87672.94
# 1;Q002_G;83450.41
# 1;Q008_D;82590.52
# 1;TP_FAIXA_ETARIA_11;80158.75
#
# ============ Características mais relevantes para o Cluster 2 ============
#
# 2;Q006_L;891394.49
# 2;Q003_E;595433.81
# 2;Q010_C;554756.76
# 2;Q008_E;553868.05
# 2;Q018_B;541433.79
# 2;Q021_B;467001.81
# 2;Q004_E;447773.68
# 2;Q001_G;428291.20
# 2;Q019_E;428133.75
# 2;Q008_D;379023.17
# 2;TP_ESCOLA_3;355014.55
# 2;Q024_D;340808.49
# 2;Q007_B;321634.60
# 2;Q017_B;316823.24
# 2;Q002_G;310191.19
# 2;Q019_D;294609.85
# 2;Q012_C;271569.52
# 2;Q024_E;264765.16
# 2;Q024_C;261307.16
# 2;Q022_E;243587.10
# 2;Q007_D;237262.01
# 2;Q009_E;232585.61
# 2;Q020_B;228105.99
# 2;Q008_B;215899.16
# 2;Q015_B;208112.63
# 2;Q013_C;206838.18
# 2;Q018_A;189297.50
# 2;Q010_A;179677.67
# 2;Q023_B;172266.14
# 2;Q024_A;166941.22
# 2;Q019_B;165567.00
# 2;Q016_A;154344.75
# 2;Q001_F;152710.80
# 2;Q021_A;143002.24
# 2;Q014_A;137837.55
# 2;Q016_B;128039.17
# 2;Q009_D;119178.40
# 2;TP_COR_RACA_1;117729.07
# 2;Q006_B;114728.85
# 2;Q013_A;111848.43
# 2;Q009_C;111704.56
# 2;Q010_D;109160.06
# 2;Q004_B;97897.38
# 2;Q002_F;90961.68
# 2;Q004_D;89488.32
# 2;Q006_K;83959.43
#
# ============ Características mais relevantes para o Cluster 3 ============
#
# 3;TP_ST_CONCLUSAO_2;297498.14
# 3;TP_ESCOLA_2;246581.89
# 3;TP_ESCOLA_1;192106.16
# 3;Q014_A;181180.18
# 3;Q010_B;175933.38
# 3;Q008_C;152293.03
# 3;Q024_B;145119.76
# 3;Q024_A;132117.45
# 3;Q006_B;128103.59
# 3;Q010_A;125789.41
# 3;Q016_B;111612.76
# 3;Q016_A;109252.01
# 3;TP_ST_CONCLUSAO_3;106568.85
# 3;Q014_B;105443.82
# 3;TP_ST_CONCLUSAO_1;93916.38
# 3;Q019_C;87107.43
#
# ============ Características mais relevantes para o Cluster 4 ============
#
# 4;TP_ST_CONCLUSAO_2;577355.53
# 4;TP_ESCOLA_2;557577.16
# 4;TP_ESCOLA_1;372817.41
# 4;TP_ST_CONCLUSAO_1;253370.78
# 4;TP_FAIXA_ETARIA_3;180500.48
# 4;Q014_A;124662.02
# 4;TP_ST_CONCLUSAO_3;117157.26
# 4;Q010_B;94504.33
